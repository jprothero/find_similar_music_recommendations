# %% [markdown]
# Idea:
#
# learn TruncatedSvd of either dislike vs like (some rating threshold), or maybe -1 and 1 for incorporating seen vs. hasn't seen
#     For different numbers of components (could look as function of n components and compute max once),
#         see how well it can reconstruct the like vs. dislike, and maybe seen vs not seen. could maybe
#             also have two separate binary matrices, seen vs not seen and like vs not like
#                 For our simple spotify one it's only seen vs. not seen
#
#
#             Anyways, basically sample some (k) users, and check the accuracy (or some other loss metric, but accuracy
#                 is probably fine)
#
#             Goal is finding the minimum number of components that gets a reasonable accuracy

# %% [markdown]
# TODO: can't test this with spotify, but could test with movie lens: does doing -1, 0, 1 (zeros implicit / sparse), work
#     better than just 0, 1 saw vs. since saw

# %% [markdown]
# TODO: setup WSL2 so we can do rapidsai UMAP, there are some interesting experiments we could do with that.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("../")

# %%
from ease_recommender import *
from npmi_recommender import *

import pickle as p

# %%
def create_mat(row, col, bool_to_int=True):
    # bool_to_int won't count duplicates in the same row, creates a different weighting basically
    if bool_to_int:
        data = np.ones_like(row, dtype=bool)
        return csr_matrix((data, (row, col))).astype(np.int64)
    else:
        data = np.ones_like(row, dtype=np.int64)
        return csr_matrix((data, (row, col)))

def check_if_all_terms_in_str(q, terms):
    for term in terms:
        if term not in q:
            return False

    return True

def get_cat2idx(category_type, D):
    if category_type == "track":
        return D["track2idx"]
    elif category_type == "album":
        return D["album2idx"]
    elif category_type == "artist":
        return D["artist2idx"]
    else:
        raise NotImplementedError

def find_match_using_terms(terms, cat2idx):
    matches = []
    for name in cat2idx.keys():
        if check_if_all_terms_in_str(name, terms):
            matches.append(name)

    if len(matches) > 1:
        raise Exception("Multiple matches found, filter down to a single match", matches)

    return matches[0]

# %%
print("loading cache data...")
D = p.load(open("cached_data/spotify_preprocessed.p", "rb"))

print("building csr matrices...")

# TODO: finish implementing track and album level recommendations

# track_mat = create_mat(D["playlist_indices"], D["track_indices"])
# album_mat = create_mat(D["playlist_indices"], D["album_indices"])
artist_mat = create_mat(D["playlist_indices"], D["artist_indices"])

print("done")
# Out:
# loading cache data...
# building csr matrices...
# done

# %%
cat2idx = get_cat2idx("artist", D)
idx2cat = {v:k for k, v in cat2idx.items()}

# %%
mat = artist_mat
mat = csr_array(mat)

mat.shape
# Out:
# (1000000, 295860)

# %%
import numpy as np

def binary_entropy(p):
    """
    Calculates Shannon entropy for a binary event (Seen/Not Seen).
    H(p) = -p*log2(p) - (1-p)*log2(1-p)
    """
    # Avoid log(0) errors with a tiny epsilon
    epsilon = 1e-9
    p = np.clip(p, epsilon, 1 - epsilon) 
    return -p * np.log2(p) - (1 - p) * np.log2(1 - p)

def total_system_entropy(probs):
    """
    Sum of entropies for all movies in the system.
    Represents total uncertainty about the user's viewing history.
    """
    return np.sum([binary_entropy(p) for p in probs])

def select_next_movie_to_query(candidate_movies, current_probs, model):
    """
    Args:
        candidate_movies: List of indices of movies we haven't asked about yet.
        current_probs: Current vector of probabilities [p_0, p_1, ... p_N] 
                       that the user has seen each movie.
        model: The probabilistic model (e.g., Bayesian Matrix Factorization)
               that holds correlations between movies.
    
    Returns:
        best_movie_index: The movie that maximizes Information Gain.
    """
    
    best_movie = None
    max_info_gain = -np.inf
    
    # 1. Calculate the entropy of our CURRENT state
    current_H = total_system_entropy(current_probs)

    # 2. Iterate through every possible question we could ask
    for movie_id in candidate_movies:
        
        # --- THE LOOK-AHEAD STEP ---
        
        # Probability the user actually answers "Yes" to this specific movie
        # (Based on our current best guess)
        prob_user_says_yes = current_probs[movie_id]
        prob_user_says_no = 1.0 - prob_user_says_yes
        
        # SCENARIO A: SIMULATE "YES" ANSWER
        # We tell the model: "Assume user definitely saw movie_id."
        # The model uses correlations to update probs for ALL other movies.
        probs_if_yes = model.get_posterior_probs(movie_id, observed_val=1)
        H_given_yes = total_system_entropy(probs_if_yes)
        
        # SCENARIO B: SIMULATE "NO" ANSWER
        # We tell the model: "Assume user definitely did NOT see movie_id."
        probs_if_no = model.get_posterior_probs(movie_id, observed_val=0)
        H_given_no = total_system_entropy(probs_if_no)
        
        # 3. Calculate Expected Entropy (Weighted Average)
        # This is the uncertainty we expect to have remaining after asking.
        expected_posterior_H = (prob_user_says_yes * H_given_yes) + \
                               (prob_user_says_no  * H_given_no)
        
        # 4. Calculate Information Gain (IG)
        # How much uncertainty did we remove?
        info_gain = current_H - expected_posterior_H
        
        # Keep track of the winner
        if info_gain > max_info_gain:
            max_info_gain = info_gain
            best_movie = movie_id
            
    return best_movie

# %%
# use two items that you believe are similar to optimize the value of lambda_

a_name = find_match_using_terms(["sgeir", "7xUZ4069zcyBM4Bn10NQ1c"], cat2idx)
# a_name = find_match_using_terms(["7fNWySjsDn74LCawyJ27EQ"], cat2idx)

a = cat2idx[a_name]
print(f"{a_name=}")
print(f"Num Rows: {artist_mat[:, a].sum()}")

# a = cat2idx[find_match_using_terms(["Fleet Foxes"], cat2idx)]

# b = cat2idx[find_match_using_terms(["Fleet Foxes"], cat2idx)]
# b = cat2idx[find_match_using_terms(["Bon Iver", "4LEiUm1SRbFMgfqnQTwUbQ"], cat2idx)]
# b = cat2idx[find_match_using_terms(["SOHN"], cat2idx)]

# b_name = find_match_using_terms(["7fNWySjsDn74LCawyJ27EQ"], cat2idx)
b_name = find_match_using_terms(["Highas"], cat2idx)
b = cat2idx[b_name]
print(f"{b_name=}")
print(f"Num Rows: {artist_mat[:, b].sum()}")
# Out:
# a_name='Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)'
# Num Rows: 1981
# b_name='Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)'
# Num Rows: 412

# %%
px = mat.mean(axis=0)

# %%
from sklearn.metrics import log_loss

# Labels must be provided. 
# valid_labels ensures the function knows both 0 and 1 exist even if sample is small
loss = log_loss(np.ones_like(px), px, labels=[0, 1])

loss
# Out:
# 12.413044749829446

# %%
from scipy.stats import entropy

# This calculates Shannon entropy for each probability p vs (1-p)
# We stack them to create shape (N, 2) so scipy sees them as distributions
probs = np.hstack([1-px, px])

# Calculate entropy (base e is standard for natural log)
binary_entropies = entropy(probs, base=np.e).sum()
binary_entropies
# print("Entropy per sample:", binary_entropies)
# Out:
# np.float64(12.598417777628557)

# %%
from scipy.special import entr

# H(p) = -p*log(p) - (1-p)*log(1-p)
binary_entropy = entr(px) + entr(1 - px)
binary_entropy.sum()
# Out:
# np.float64(229.62557988409768)

# %%
import numpy as np

def binary_entropy(px):
    # A tiny number (epsilon) to prevent log(0)
    eps = 1e-15 
    px = np.clip(px, eps, 1 - eps)

    return (-px * np.log(px) - (1 - px) * np.log(1 - px)).sum()

# %%
def get_entropy_for_mask(mask):
    mat_subset = mat[mask]

    mat_subset.shape[0] / mat.shape[0]

    px_new = mat_subset.mean(axis=0)

    ent_new = binary_entropy(px_new)
    
    return ent_new * mask.mean()

# %%
from tqdm.auto import tqdm

# %%
info_gain = []
ent_old = binary_entropy(px)
print(ent_old)
for i in tqdm(np.argsort(-px)[:3]):
    # in theory you'd want to get the entropy for the inverse mask too..
    
    mask = mat[:, i].toarray().astype("bool")
    
    info_gain.append((get_entropy_for_mask(mask) + get_entropy_for_mask(~mask)) - ent_old)
    print(info_gain[-1])

print(np.argmin(np.array(info_gain) - ent_old))
# Out:
# 229.62557988409768
#   0%|          | 0/3 [00:00<?, ?it/s]
# -6.498021034650634
# -4.154881323908029
# -4.522551716863546
# 0

# %%
entr(1 - px_new).sum()
# Out:
# np.float64(-inf)

# %%
ent_new
# Out:
# np.float64(-inf)

# %%
px_new.min()
# Out:
# np.float64(0.0)

# %%
# Out:
# np.True_

# %%
px[:50]
# Out:
# array([0.022392, 0.040774, 0.097468, 0.071479, 0.031928, 0.072566,
#        0.014086, 0.02828 , 0.045638, 0.022094, 0.016611, 0.007538,
#        0.019823, 0.026058, 0.095501, 0.008459, 0.037234, 0.014495,
#        0.003342, 0.01611 , 0.006185, 0.010995, 0.074693, 0.033901,
#        0.070627, 0.010654, 0.013848, 0.040067, 0.092492, 0.021905,
#        0.04454 , 0.035883, 0.026621, 0.011706, 0.001392, 0.050512,
#        0.012008, 0.013691, 0.000149, 0.000122, 0.000126, 0.003807,
#        0.003804, 0.003719, 0.029498, 0.005593, 0.000657, 0.005188,
#        0.039271, 0.032741])

# %%
len(px)
# Out:
# 295860

# %%
len(px_new)
# Out:
# 295860

# %%
entropy(px, base=np.e).sum()
# Out:
# np.float64(12.598417777628557)

# %%
mask[mask]

# %%
mat
# Out:
# <Compressed Sparse Row sparse array of dtype 'int64'
# 	with 38088211 stored elements and shape (1000000, 295860)>

# %%
# import numpy as np

# # A tiny number (epsilon) to prevent log(0)
# eps = 1e-15 
# px = np.clip(px, eps, 1 - eps)

# binary_entropy = -px * np.log(px) - (1 - px) * np.log(1 - px)
# binary_entropy.sum()

# %%
probs.shape
# Out:
# (591720,)

# %%
import torch

# %%
torch.tensor(px)

# %%
# torch.functional.F.binary_cross_entropy(torch.tensor(px), torch.tensor(np.ones_like(px)))

# %%
X = mat.T @ mat

# to convert to probabilities
# X.data /= mat.shape[0]

X.shape
# Out:
# (295860, 295860)

# %%
counts = X.diagonal()

keeps = counts >= 256

print("keeps.mean()", keeps.mean())

keep_inds = np.where(keeps)[0]
# Out:
# keeps.mean() 0.037892922328128166

# %%
counts[a]
# Out:
# np.int64(1981)

# %%
counts[b]
# Out:
# np.int64(412)

# %%
X2 = X[:, keep_inds][keep_inds, :].T

# %%
X2.shape
# Out:
# (11211, 11211)

# %%
import numpy as np
import scipy.sparse as sp
from scipy.sparse.linalg import cg, LinearOperator

def train_ease_dense(G, lambda_reg=500.0):
    """
    Computes the EXACT, FULL dense EASE weight matrix.
    
    Args:
        G (sp.spmatrix or np.ndarray): Co-occurrence matrix (N x N).
        lambda_reg (float): L2 regularization parameter.
        
    Returns:
        np.ndarray: The dense weight matrix B (N x N).
    """
    # 1. Convert to dense and add regularization to diagonal
    # We use (G + lambda * I)
    if sp.issparse(G):
        G_dense = G.toarray()
    else:
        G_dense = G.copy()
        
    G_dense = G_dense.astype(np.float64)
        
    n_items = G_dense.shape[0]
    indices = np.arange(n_items)
    
    G_dense[indices, indices] += lambda_reg

    # 2. Invert the matrix P = (G + lambda_I)^-1
    # Using specialized hermitian solver (eigh) is often more stable for symmetric matrices,
    # but inv is standard and usually faster for this purpose.
    P = np.linalg.inv(G_dense)

    # 3. Calculate B = I - P * diag(1/diag(P))
    # Effectively: B_ij = - P_ij / P_jj  (if i != j)
    #              B_ii = 0
    diag_P = np.diag(P)
    
    # We divide every column j by P_jj
    B = P / -diag_P[None, :]
    
    # 4. Enforce zero constraint on diagonal
    B[indices, indices] = 0.0
    
    return B

# %%
# %%time

B = train_ease_dense(X2, lambda_reg=100)
B_orig = B
B = (B + B.T)/2

metric = (
    keep_inds[np.argsort(-B[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# CPU times: total: 2min 45s
# Wall time: 25 s
# 2.0

# %%
idx2cat[keep_inds[np.argsort(-B[keep_inds.tolist().index(a)])][0]]
# Out:
# 'Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)'

# %%
keep_inds[np.argsort(-B[keep_inds.tolist().index(a)])]#.tolist().index(b)
# Out:
# array([ 5971,   268,   530, ...,  7687, 21238, 12233], shape=(11211,))

# %%
best = keep_inds[np.argsort(-B[keep_inds.tolist().index(b)])]

top_k = 100

for i in best[:top_k]:
    print(idx2cat[i])
# Out:
# Tame Impala (spotify:artist:5INjqkS1o8h1imAzPqGZBb)
# AURORA (spotify:artist:1WgXqy2Dd70QQOU7Ay074N)
# Susanne Sundfør (spotify:artist:54KCNI7URCrG6yjQK3Ukow)
# London Grammar (spotify:artist:3Bd1cgCjtCI32PYvDC3ynO)
# Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)
# MUNA (spotify:artist:6xdRb2GypJ7DqnWAI2mHGn)
# Majical Cloudz (spotify:artist:4BEYBN6NCPrFk3sOLMTby3)
# Alice Boman (spotify:artist:3WiytRnvoL0kT3oAGl9TCt)
# Birdy (spotify:artist:2WX2uTcsvV5OnS0inACecP)
# Hozier (spotify:artist:2FXC3k01G6Gw61bmprjgqS)
# Lemaitre (spotify:artist:4CTKqs11Zgsv8EZTVzx764)
# RY X (spotify:artist:2KjAo6wVc9d2WcxdxSArpV)
# Joseph (spotify:artist:5Wfvw7rDz7HA6gE2z6QhqO)
# Rubblebucket (spotify:artist:6xriZDSK3wPXhOoZXr9fzF)
# Max Jury (spotify:artist:3MuPVbFDynbq9zRTAqjRxi)
# Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO
# Anne-Marie (spotify:artist:1zNqDE7qDGCsyzJwohVaoX)
# Transviolet (spotify:artist:7ixzNQXQ64I2ayrtyhlF7i)
# Son Lux (spotify:artist:3kZdsaTYgaaolNxpnJ4iDe)
# CHVRCHES (spotify:artist:3CjlHNtplJyTf9npxaPl5w)
# Matrimony (spotify:artist:4V5UtbLYaFishr7psURF3Q)
# Young Thug (spotify:artist:50co4Is1HCEo8bhOyUWKpn)
# Flight Facilities (spotify:artist:1lc8mnyGrCLtPhCoWjRxjM)
# Moby (spotify:artist:3OsRAKCvk37zwYcnzRf5XF)
# Missy Elliott (spotify:artist:2wIVse2owClT7go1WT98tk)
# Pearl Jam (spotify:artist:1w5Kfo2jwwIPruYS2UWh56)
# alt-J (spotify:artist:3XHO7cRUPCLOr6jwp8vsx5)
# Júníus Meyvant (spotify:artist:5IL5awl9gUcb2ez9IgmW26)
# Great Good Fine Ok (spotify:artist:422RLznpwUa5FsQgnTlgUH)
# Mr Little Jeans (spotify:artist:0B2SlMW40Hs9mijOi1cDyf)
# KOLAJ (spotify:artist:0hhL0iOf9ebHlwxWQyeH2w)
# Soko (spotify:artist:4Q3f2YYH4gQxWFS3WY5G3j)
# Glass Animals (spotify:artist:4yvcSjfu4PC0CYQyLy4wSq)
# Emma Louise (spotify:artist:1A96iePIMNFBjLrjXEl718)
# Daniela Andrade (spotify:artist:0WfaItAbs4vlgIA1cuqGtJ)
# TOKiMONSTA (spotify:artist:3VwKSHAfgzV1DOHV0aANCI)
# Peaches (spotify:artist:1gkSl4XpHIHI4I1WQbfXOE)

# %%
c_name = find_match_using_terms(["Gabrielle (spotify:artist:4OovmAu23KrDlDQI2UbneL)"], cat2idx)
c = cat2idx[c_name]
print(f"{c_name=}")
print(f"Num Rows: {artist_mat[:, c].sum()}")
# Out:
# c_name='Gabrielle (spotify:artist:4OovmAu23KrDlDQI2UbneL)'
# Num Rows: 71

# %%
import os
# 1. Set Backend to PyTorch BEFORE importing Keras
os.environ["KERAS_BACKEND"] = "torch"

import torch
assert torch.cuda.is_available()

import keras
import numpy as np

import math

# --- 2. CUSTOM ONE CYCLE SCHEDULER ---
# Keras doesn't have a native OneCycle callback, so we write this simple one.
class OneCycleLR(keras.callbacks.Callback):
    def __init__(self, max_lr, total_steps, warmup_fraction=0.3):
        super().__init__()
        self.max_lr = max_lr
        self.total_steps = total_steps
        self.warmup_steps = int(total_steps * warmup_fraction)
        self.step = 0
        
    def on_train_batch_begin(self, batch, logs=None):
        self.step += 1
        # 1. Linear Warmup
        if self.step < self.warmup_steps:
            pct = self.step / self.warmup_steps
            lr = self.max_lr * pct
        # 2. Cosine Decay
        else:
            pct = (self.step - self.warmup_steps) / (self.total_steps - self.warmup_steps)
            # Cosine decay from max_lr to 0
            lr = self.max_lr * 0.5 * (1 + math.cos(math.pi * pct))
            
        self.model.optimizer.learning_rate.assign(lr)

N_SAMPLES, N_FEATURES = B.shape
X = (B - B.mean()) / B.std()
# X = B

mul = 8
hidden_dim = 16 * mul

activation = "gelu"

# --- 2. DEFINE MODELS (SEQUENTIAL) ---

# A. The Encoder (Forward Transform)
# Compresses 100 features -> 2 features
encoder = keras.Sequential([
    keras.layers.Input(shape=(N_FEATURES,)),
#     keras.layers.Dense(256 * mul, activation=activation),
    keras.layers.Dense(128 * mul, activation=activation),
#     keras.layers.BatchNormalization(),
    keras.layers.Dense(64 * mul, activation=activation),
#     keras.layers.BatchNormalization(),
    keras.layers.Dense(32 * mul, activation=activation),
#     keras.layers.BatchNormalization(),
    keras.layers.Dense(hidden_dim, activation='linear')  # The "Bottleneck"
])

# B. The Decoder (Inverse Transform)
# Expands 2 features -> 100 features
decoder = keras.Sequential([
    keras.layers.Input(shape=(hidden_dim,)),
#     keras.layers.BatchNormalization(),
    keras.layers.Dense(32 * mul, activation=activation),
#     keras.layers.BatchNormalization(),
    keras.layers.Dense(64 * mul, activation=activation),
#     keras.layers.BatchNormalization(),
    keras.layers.Dense(128 * mul, activation=activation),
#     keras.layers.BatchNormalization(),
#     keras.layers.Dense(256 * mul, activation=activation),
    keras.layers.Dense(N_FEATURES, activation='linear') # Match input scale
])

# C. The Full Autoencoder
# This is just the two combined. We train this one.
autoencoder = keras.Sequential([
    encoder,
    decoder
])

EPOCHS = 10
MAX_LR = 1e-3
BATCH_SIZE = 32
STEPS_PER_EPOCH = len(X) // BATCH_SIZE
TOTAL_STEPS = EPOCHS * STEPS_PER_EPOCH

opt = keras.optimizers.AdamW(learning_rate=MAX_LR)

# opt = keras.optimizers.AdamW(
#     learning_rate=MAX_LR,     # Initial value (overwritten by callback immediately)
#     weight_decay=1e-4,        # Regularization "done right"
#     use_ema=True,             # <--- HUGE TRICK for generative models
#     ema_momentum=0.999,       # How smooth to keep the average
#     global_clipnorm=1.0       # Stabilizes training
# )

# --- 3. COMPILE & TRAIN ---
autoencoder.compile(optimizer=opt, loss='mse')

print("Training Autoencoder...")
autoencoder.fit(X, X, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=1, 
                callbacks=[
        OneCycleLR(max_lr=MAX_LR, total_steps=TOTAL_STEPS)
    ])
# Out:
# Training Autoencoder...
# Epoch 1/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.9943
# Epoch 2/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.9360
# Epoch 3/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.9092
# Epoch 4/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - loss: 0.8974
# Epoch 5/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.8791
# Epoch 6/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.8498
# Epoch 7/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.8184
# Epoch 8/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.7855
# Epoch 9/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.7591
# Epoch 10/10
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.7453

# %%
# --- 4. USE IT ---

# Forward Transform (Dimensionality Reduction)
# 100 features -> 2 features
embedding = encoder.predict(X)

# Inverse Transform (Reconstruction)
# 2 features -> 100 features
reconstructed = decoder.predict(embedding)

print("\n--- RESULTS ---")
print(f"Original Data Shape:    {X.shape}")           # (10000, 100)
print(f"Compressed Embedding:   {embedding.shape}")   # (10000, 2)
print(f"Reconstructed Data:     {reconstructed.shape}") # (10000, 100)
# Out:
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
#
# --- RESULTS ---
# Original Data Shape:    (11211, 11211)
# Compressed Embedding:   (11211, 128)
# Reconstructed Data:     (11211, 11211)

# %%
B_alt = reconstructed

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 73.5

# %%
B_alt = reconstructed

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 81.5

# %%
B_alt = reconstructed

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 101.5

# %%
B_alt = reconstructed

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 126.5

# %%
B_alt = reconstructed

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 145.5

# %%
B_alt = reconstructed

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 242.0

# %%
B_alt = reconstructed

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 288.5

# %%
embedding.shape
# Out:
# (11211, 64)

# %%
from sklearn.decomposition import PCA

pca = PCA(embedding.shape[-1])

B_alt = pca.inverse_transform(pca.fit_transform(B))

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 186.0

# %%
from sklearn.decomposition import PCA

pca = PCA(embedding.shape[-1])

B_alt = pca.inverse_transform(pca.fit_transform(B))

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 269.5

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

def run_experiment(steps=50, seed=42):
    np.random.seed(seed)
    
    # 1. The True Goal (Sampled from Isotropic Gaussian)
    true_goal = np.random.randn(2)
    
    # 2. Initial Belief
    # Start offset to visualize the travel
    current_mu = np.array([-2.0, -2.0]) 
    current_cov = np.eye(2) * 2.0  # Large initial uncertainty
    
    history = []
    
    # Heuristic: mu_new = mu_old + learning_rate * (winner - loser)
    learning_rate = 0.2
    decay = 0.95 # Annealing the covariance
    
    for t in range(steps):
        history.append({
            'mu': current_mu.copy(),
            'cov': current_cov.copy()
        })
        
        # 3. Sample two points from belief
        s1 = np.random.multivariate_normal(current_mu, current_cov)
        s2 = np.random.multivariate_normal(current_mu, current_cov)
        
        # 4. Pick closer one
        d1 = np.linalg.norm(s1 - true_goal)
        d2 = np.linalg.norm(s2 - true_goal)
        
        if d1 < d2:
            winner, loser = s1, s2
        else:
            winner, loser = s2, s1
            
        # 5. Use the diff to move
        diff = winner - loser
        
        # Update Mean & Covariance
        current_mu = current_mu + learning_rate * diff
        current_cov = current_cov * decay
        
    return history, true_goal

def plot_covariance_ellipse(ax, mu, cov, color='blue', alpha=0.2):
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    vals, vecs = vals[order], vecs[:, order]
    theta = np.degrees(np.arctan2(*vecs[:, 0][::-1]))
    w, h = 2 * 2 * np.sqrt(vals) # 2-std ellipse
    ell = Ellipse(xy=mu, width=w, height=h, angle=theta, color=color, alpha=alpha)
    ax.add_artist(ell)
    ax.scatter(mu[0], mu[1], c=color, s=20, marker='x')

def visualize_progression(history, true_goal):
    total_steps = len(history)
    indices = [0, total_steps//4, total_steps//2, total_steps-1]
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    
    all_mus = np.array([h['mu'] for h in history])
    xs = np.concatenate([all_mus[:,0], [true_goal[0]]])
    ys = np.concatenate([all_mus[:,1], [true_goal[1]]])
    xlim = (xs.min() - 2, xs.max() + 2)
    ylim = (ys.min() - 2, ys.max() + 2)

    for i, idx in enumerate(indices):
        ax = axes[i]
        state = history[idx]
        plot_covariance_ellipse(ax, state['mu'], state['cov'], color='blue', alpha=0.3)
        ax.scatter(true_goal[0], true_goal[1], c='red', s=100, marker='*', label='True Goal')
        if idx > 0:
            past_mus = np.array([h['mu'] for h in history[:idx+1]])
            ax.plot(past_mus[:,0], past_mus[:,1], 'k--', alpha=0.5)
        
        ax.set_title(f"Step {idx}")
        ax.set_xlim(xlim); ax.set_ylim(ylim)
        ax.grid(True, alpha=0.3)

    plt.suptitle("Thompson Sampling Explorer: Pairwise Difference Updates", fontsize=16)
    plt.tight_layout()
    plt.show()

# Run
history, true_goal = run_experiment(steps=40)
visualize_progression(history, true_goal)

# %%
# %%time

import umap

distance_matrix = -B

# 3. Run UMAP with metric='precomputed'
reducer = umap.UMAP(
    n_neighbors=15, 
    min_dist=0, 
    n_components=10, 
    metric='precomputed' # <--- This tells UMAP the input is a distance matrix
)

# Pass the DISTANCE matrix, not the raw data
embedding = reducer.fit_transform(distance_matrix)
# Out:
# C:\Users\johns\miniconda3\envs\recsys\lib\site-packages\umap\umap_.py:1865: UserWarning: using precomputed metric; inverse_transform will be unavailable
#   warn("using precomputed metric; inverse_transform will be unavailable")
# CPU times: total: 44.2 s
# Wall time: 3.15 s

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

inverter = KNeighborsRegressor(n_neighbors=3, weights='distance')

keeps = list(set(range(len(keep_inds))) - set([keep_inds.tolist().index(a), keep_inds.tolist().index(b)]))

inverter.fit(embedding[keeps], B[keeps])

metric = (
    keep_inds[np.argsort(-inverter.predict(embedding[keep_inds.tolist().index(a)][None, :])[0]).tolist().index(b)]
    + keep_inds[np.argsort(-inverter.predict(embedding[keep_inds.tolist().index(b)][None, :])[0]).tolist().index(a)]
)/2

metric
# Out:
# np.float64(10769.0)

# %%
distance_matrix = (B + B.T)/2
distance_matrix = 1 - ((distance_matrix - distance_matrix.min()) / (distance_matrix.max() - distance_matrix.min()))

# %%
# %%time

from sklearn.manifold import MDS

# --- STEP 2: RUN MDS ---
# dissimilarity='precomputed' is key here
mds = MDS(
    n_components=20, 
    dissimilarity='precomputed', 
    random_state=42, 
    n_jobs=-1,  # Use all CPU cores
#     max_iter=300,
    n_init=1
)

embedding = mds.fit_transform(distance_matrix)
# Out:
# CPU times: total: 609 ms
# Wall time: 38.4 s

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

inverter = KNeighborsRegressor(n_neighbors=3, weights='distance')

keeps = list(set(range(len(keep_inds))) - set([keep_inds.tolist().index(a), keep_inds.tolist().index(b)]))

inverter.fit(embedding[keeps], B[keeps])

metric = (
    keep_inds[np.argsort(-inverter.predict(embedding[keep_inds.tolist().index(a)][None, :])[0]).tolist().index(b)]
    + keep_inds[np.argsort(-inverter.predict(embedding[keep_inds.tolist().index(b)][None, :])[0]).tolist().index(a)]
)/2

metric
# Out:
# np.float64(6227.0)

# %%
inverter.predict(embedding[keep_inds.tolist().index(a)][None, :])[0]
# Out:
# array([-8.48296939e-04, -2.07946792e-03, -2.86551294e-03, ...,
#         1.50392507e-03, -8.58506517e-05, -3.42996833e-05], shape=(11211,))

# %%
B_alt = inverter.predict(embedding)

# %%
metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 5594.5

# %%
metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 5594.5

# %%
from sklearn.decomposition import PCA, FastICA   
# from sklearn.decomposition import KernelPCA

pca = PCA(128)
# pca = FastICA(100)
# pca = KernelPCA(
#     n_components=1, 
#     kernel='rbf', 
#     gamma=15, 
#     fit_inverse_transform=True,
#     n_jobs=-1
# )

B_alt = pca.inverse_transform(pca.fit_transform(B))

metric = (
    keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(a)])].tolist().index(b)
    + keep_inds[np.argsort(-B_alt[keep_inds.tolist().index(b)])].tolist().index(a)
)/2

metric
# Out:
# 209.0

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu130
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu130
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu130/torch-2.9.1%2Bcu130-cp310-cp310-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu130/torchvision-0.24.1%2Bcu130-cp310-cp310-win_amd64.whl.metadata (6.1 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from torch) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from torchvision) (12.0.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cu130/torch-2.9.1%2Bcu130-cp310-cp310-win_amd64.whl (1862.1 MB)
#    ---------------------------------------- 0.0/1.9 GB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9
4 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.4 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.4 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 GB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 GB 12.1 MB/s  0:02:20
# Downloading https://download.pytorch.org/whl/cu130/torchvision-0.24.1%2Bcu130-cp310-cp310-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------------- -------------------------- 2.9/8.3 MB 15.3 MB/s eta 0:00:01
#    --------------------------- ------------ 5.8/8.3 MB 15.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 14.3 MB/s  0:00:00
# Using cached fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock, torch, torchvision
#
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------------- ---------------------- 3/7 [fsspec]
#    ----------------- ---------------------- 3/7 [fsspec]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------------- 7/7 [torchvision]
#
# Successfully installed filelock-3.20.0 fsspec-2025.12.0 mpmath-1.3.0 networkx-3.4.2 sympy-1.14.0 torch-2.9.1+cu130 torchvision-0.24.1+cu130

# %%
pip install --upgrade keras
# Out:
# Requirement already satisfied: keras in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (3.12.0)
# Requirement already satisfied: absl-py in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from keras) (2.2.6)
# Requirement already satisfied: rich in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from keras) (0.18.0)
# Requirement already satisfied: ml-dtypes in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\johns\miniconda3\envs\recsys\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
t

# %%
best = keep_inds[np.argsort(-B[keep_inds.tolist().index(a)])]

top_k = 100

for i in best[:top_k]:
    print(idx2cat[i])
# Out:
# Sylvan Esso (spotify:artist:39vA9YljbnOApXKniLWBZv)
# Hozier (spotify:artist:2FXC3k01G6Gw61bmprjgqS)
# Chet Faker (spotify:artist:2Q0MyH5YMI5HPQjFjlq5g3)
# Milky Chance (spotify:artist:1hzfo8twXdOegF3xireCYs)
# José González (spotify:artist:6xrCU6zdcSTsG2hLrojpmI)
# London Grammar (spotify:artist:3Bd1cgCjtCI32PYvDC3ynO)
# James Vincent McMorrow (spotify:artist:7FDlvgcodNfC0IBdWevl4u)
# SOHN (spotify:artist:6XZYAWJLL8UIbxAqjKj3cg)
# Glass Animals (spotify:artist:4yvcSjfu4PC0CYQyLy4wSq)
# James Blake (spotify:artist:53KwLdlmrlCelAZMaLVZqU)
# Coldplay (spotify:artist:4gzpq5DPGxSnKTe4SA8HAU)
# Panama (spotify:artist:3W9UldYu0xJcaOAw2SUTDI)
# alt-J (spotify:artist:3XHO7cRUPCLOr6jwp8vsx5)
# Lo-Fang (spotify:artist:5EDkJDlRNcMs3ewliB24QA)
# Max Frost (spotify:artist:7r8xR0LmnaAM623MmRDn1V)
# Iron & Wine (spotify:artist:4M5nCE77Qaxayuhp3fVn4V)
# Dustin Tebbutt (spotify:artist:0z9hynUsIjf0ddI4uHqPWX)
# Matt Corby (spotify:artist:7CIW23FQUXPc1zebnO1TDG)
# Bear's Den (spotify:artist:0nJaMZM8paoA5HEUTUXPqi)
# Allman Brown (spotify:artist:239Y6QdFqVFfdsw6moqSEN)
# MS MR (spotify:artist:4XaUmUGjidSklcDHxv3XWf)
# PHOX (spotify:artist:3ix4iw2URncSdE7X292bXy)
# Broken Bells (spotify:artist:6dgwEwnK0YtDfS9XhRwBTG)
# Frank Ocean (spotify:artist:2h93pZq0e7k5yf4dywlkpM)
# Novo Amor (spotify:artist:0rZp7G3gIH6WkyeXbrZnGi)
# Beck (spotify:artist:3vbKDsSS70ZX9D2OcvbZmS)
# Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO
# Sticky Fingers (spotify:artist:3ZGr7nQBXDU2WhyXgRVbt0)
# Vallis Alps (spotify:artist:7qhWa7UI1QNZNDnzYwAYZm)
# Hundred Waters (spotify:artist:108ugtkRFQzP9nGgNiyERO)
# Kaleo (spotify:artist:7jdFEYD2LTYjfwxOdlVjmc)
# Kings of Leon (spotify:artist:2qk9voo8llSGYcZ6xrBzKx)
# Who Is Fancy (spotify:artist:5QSx2vpiSchSeCwc0qmfNI)
# Toro y Moi (spotify:artist:6O4EGCCb6DoIiR6B1QCQgp)
# Nickel Creek (spotify:artist:3bcLBxvaI7GsBzGp3WHnwQ)
# Washed Out (spotify:artist:5juOkIIy18sFw9L30syt1Z)
# Manchester Orchestra (spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f)
# Only Real (spotify:artist:5cyHu7tidauRJ9UawaPwG5)
# Jack Garratt (spotify:artist:1Zp054Jc86WVKCxKEqZGOA)
# Major Lazer (spotify:artist:738wLrAtLtCtFOLvQBXOXp)
# Big Scary (spotify:artist:4mLYW48jy9Pwv6KpT74Evf)
# Bibio (spotify:artist:0qzzGu8qpbXYpzgV52wOFT)
# Family of the Year (spotify:artist:7zsin6IgVsR1rqSRCNYDwq)
# MØ (spotify:artist:0bdfiayQAKewqEvaU6rXCv)
# St. Paul & The Broken Bones (spotify:artist:4fXkvh05wFhuH77MfD4m9o)
# Chromeo (spotify:artist:2mV8aJphiSHYJf43DxL7Gt)
# Justin Bieber (spotify:artist:1uNFoZAHBGtllmzznpCI3s)
# POLIÇA (spotify:artist:34vLhockmYhf3LgznwyNaQ)
# Zedd (spotify:artist:2qxJFvFYMEDqd7ui6kSAcq)
# Haux (spotify:artist:1ifC4znYCvmMSJ0rght5JS)
# Michael Kiwanuka (spotify:artist:0bzfPKdbXL5ezYW2z3UGQj)
# Neulore (spotify:artist:6SLbaDa56f1CZlUNuF0gk3)
# Phoenix (spotify:artist:1xU878Z1QtBldR7ru9owdU)
# Caroline Smith (spotify:artist:47blM5Op3BJODxUJImwdYE)
# Dr. Dog (spotify:artist:4mLJ3XfOM5FPjSAWdQ2Jk7)
# Klangkarussell (spotify:artist:041iTeoMIwXMlShuQPIVKo)
# Matthew And The Atlas (spotify:artist:0lSENl3bteP8p2NbiSP7RM)

# %%
# best = np.argsort(np.linalg.norm(Y_alt - y_alt[None, :], axis=-1))
# # best = np.argsort(np.linalg.norm(Y - y[None, :], axis=-1))
# # best = np.argsort(-svd.inverse_transform(recommender.mu[None, :])[0])

# top_k = 100

# for i in best[:top_k]:
#     print(idx2cat[i])

# %%
# --- 2. Setup Data ---
D = 5   # Small dimension for demo speed
M = 10  # Number of items
items = np.random.randn(M, D)
items /= np.linalg.norm(items, axis=1, keepdims=True)

# Assign fake "Names" so you can choose based on a rule
# e.g., Try to consistently pick "Sci-Fi" items
genres = ["Action", "Sci-Fi", "Romance", "Comedy", "Horror"]
item_labels = [f"{genres[i%5]} Movie #{i}" for i in range(M)]



    # --- Result ---
    print("\n--- Learning Finished ---")
    final_scores = items @ sampler.mu
    best_idx = np.argmax(final_scores)
    print(f"Based on your answers, I think your favorite item is: {item_labels[best_idx]}")

# Run it
if __name__ == "__main__":
    interactive_pairwise_search(items, item_labels)

# %%
# %%time

svd = TruncatedSVD(128)

X = svd.fit_transform(mat)
# Out:
# CPU times: total: 3min 17s
# Wall time: 1min 13s

# %%
# import numpy as np
# import warnings

# # Suppress warnings for cleaner output
# # warnings.filterwarnings("ignore")

# class KnowledgeGradientRecommender:
#     def __init__(self, item_embeddings, noise_variance=0.25):
#         """
#         Initialize the recommender.
        
#         Args:
#             item_embeddings (np.ndarray): Matrix of shape (n_items, n_features).
#             noise_variance (float): Assumed variance of the user feedback noise.
#                                     For binary 0/1, 0.25 is a reasonable proxy.
#         """
#         self.X = item_embeddings.astype(np.float64)
#         self.n_items, self.n_features = self.X.shape
#         self.noise_var = noise_variance
        
#         # 1. Initialization (Constraint: Independent Variances)
#         # We start with 0 mean and unit variance for all latent components.
#         self.mu = np.zeros(self.n_features)
        
#         # Diagonal of the covariance matrix (sigma^2_d)
#         # Represents uncertainty for each SVD component.
#         self.sigma_sq = np.ones(self.n_features) 
        
#         # Mask to track seen items
#         self.seen_mask = np.zeros(self.n_items, dtype=bool)

#     def _compute_expected_max_improvement(self, a, b):
#         """
#         Robust version of Algorithm A.
#         Handles parallel lines (duplicate b values) by keeping only the best 'a'.
#         """
#         # 1. Deduplicate Slopes (Handle Parallel Lines)
#         # We sort by b (primary) and a (secondary).
#         # If multiple items have the same 'b', the one with the highest 'a'
#         # will appear LAST in that group.
#         sort_idx = np.lexsort((a, b))
#         a_sorted = a[sort_idx]
#         b_sorted = b[sort_idx]

#         # Create a mask to keep only the *last* occurrence of each unique b value
#         # (which corresponds to the max 'a' for that 'b' due to lexsort).
#         # We use a small epsilon for float comparison stability.
#         diff_b = np.diff(b_sorted)
#         keep_mask = np.concatenate((diff_b > 1e-9, [True]))
        
#         a = a_sorted[keep_mask]
#         b = b_sorted[keep_mask]

#         # If only one line remains, there is no variance/intersection to explore
#         if len(a) < 2:
#             return 0.0

#         # 2. Standard Algorithm A (Convex Hull Scan)
#         # hull indices refer to the 'a' and 'b' arrays we just filtered
#         hull = [0]
        
#         for i in range(1, len(a)):
#             while len(hull) >= 2:
#                 i_prev = hull[-1]
#                 i_prev2 = hull[-2]
                
#                 # Intersection z value between prev and prev2
#                 # Note: b is strictly increasing now, so denominator > 0
#                 z_prev = (a[i_prev] - a[i_prev2]) / (b[i_prev2] - b[i_prev])
                
#                 # Intersection z value between new and prev
#                 z_new = (a[i] - a[i_prev]) / (b[i_prev] - b[i])
                
#                 # If the new intersection is to the left of the old one,
#                 # the middle line (i_prev) is dominated. Pop it.
#                 if z_prev >= z_new:
#                     hull.pop()
#                 else:
#                     break
#             hull.append(i)
            
#         hull = np.array(hull)
#         a_h = a[hull]
#         b_h = b[hull]
        
#         if len(hull) < 2:
#             return 0.0

#         # 3. Integration
#         # Calculate intersections z_k where line k and k+1 meet
#         z = (a_h[:-1] - a_h[1:]) / (b_h[1:] - b_h[:-1])
#         z = np.concatenate(([-np.inf], z, [np.inf]))
        
#         def pdf(x): return np.exp(-0.5 * x**2) / np.sqrt(2 * np.pi)
#         from scipy.special import ndtr as cdf
        
#         value = 0.0
#         for i in range(len(hull)):
#             # Probability mass in the interval
#             p_mass = cdf(z[i+1]) - cdf(z[i])
            
#             # Expected value of truncated normal in the interval
#             # E[Z | L < Z < U] * P(L < Z < U) = pdf(L) - pdf(U)
#             e_z_term = pdf(z[i]) - pdf(z[i+1])
            
#             value += a_h[i] * p_mass + b_h[i] * e_z_term
            
#         # KG is the Expected Max Improvement over the CURRENT Max
#         # Note: We use the max of the *filtered* a, which is the same as max(original a)
#         current_max = np.max(a)
        
#         return max(0.0, value - current_max)

#     def select_next_item(self):
#         """
#         Calculates the Knowledge Gradient for every unseen item.
#         Returns the index of the item that maximizes Value of Information.
#         """
#         unseen_indices = np.where(~self.seen_mask)[0]
#         if len(unseen_indices) == 0:
#             return None
        
#         X_unseen = self.X[unseen_indices]
        
#         # 1. Pre-calculate 'a' vector (Current Posterior Mean Estimates)
#         # a_i = mu^T x_i
#         a_all = self.X @ self.mu
#         current_max_a = np.max(a_all)
        
#         # 2. Iterate over candidates x_n (the item we might explore)
#         # To compute KG(x_n), we need to see how x_n affects the WHOLE system.
#         kg_scores = []
        
#         # Precompute Sigma * X.T for all items (Diagonal Sigma makes this fast)
#         # Sigma is vector (diagonal), so this is elementwise broadcast
#         # Shape: (n_items, n_features)
#         Sigma_X = self.sigma_sq[None, :] * self.X
        
#         for i, idx in enumerate(tqdm(unseen_indices)):
#             x_candidate = X_unseen[i]
            
#             # Predictive Variance for this candidate: sigma_tilde^2 = x^T Sigma x + noise
#             # Note: self.sigma_sq is a vector (diagonal matrix)
#             # x_candidate^2 * sigma_sq sum
#             pred_var = np.dot(x_candidate**2, self.sigma_sq) + self.noise_var
            
#             # The 'change vector' direction (tilde_sigma in literature)
#             # This is the vector that scales Z to create the new posterior mean.
#             # Delta_mu = (Sigma * x) / sqrt(pred_var) * Z
#             # change_vec shape: (n_features,)
#             change_vec = (x_candidate * self.sigma_sq) / np.sqrt(pred_var)
            
#             # Now we compute 'b' for ALL items (j=1...N) based on candidate x_n
#             # b_j = x_j^T * change_vec
#             b_all = self.X @ change_vec
            
#             # Compute KG value using Algorithm A
#             kg_val = self._compute_expected_max_improvement(a_all, b_all)
#             kg_scores.append(kg_val)
            
#         best_local_idx = np.argmax(kg_scores)
#         return unseen_indices[best_local_idx]

#     def update_belief(self, item_idx, feedback):
#         """
#         Updates the internal embeddings (mu and sigma) based on feedback.
#         Forces the posterior covariance to remain diagonal (Variational approx).
#         """
#         x = self.X[item_idx]
#         y = float(feedback) # 1.0 or 0.0
        
#         # 1. Calculate Standard Linear Gaussian Posterior Mean
#         # posterior_mu = prior_mu + (Sigma x / (x^T Sigma x + noise)) * (y - x^T prior_mu)
        
#         pred_mean = np.dot(x, self.mu)
#         pred_var = np.dot(x**2, self.sigma_sq) + self.noise_var
        
#         kalman_gain = (self.sigma_sq * x) / pred_var
        
#         # Update Mean
#         self.mu = self.mu + kalman_gain * (y - pred_mean)
        
#         # 2. Update Covariance (Diagonal Enforcement)
#         # True update: Sigma_new = Sigma - (Sigma x x^T Sigma) / pred_var
#         # We only keep the diagonal of the update term.
#         # Diagonal element j: (sigma_j^2 * x_j)^2 / pred_var
        
#         covariance_reduction = (self.sigma_sq * x)**2 / pred_var
#         self.sigma_sq = self.sigma_sq - covariance_reduction
        
#         # Mark as seen
#         self.seen_mask[item_idx] = True
        
#         # Optional: Print stats
#         print(f"   -> Updated Belief. Top predicted score: {np.max(self.X @ self.mu):.4f}")

# %%
class FastBayesianRecommender:
    def __init__(self, item_embeddings, mu, noise_variance=0.25):
        self.X = item_embeddings.astype(np.float64)
        self.n_items, self.n_features = self.X.shape
        self.noise_var = noise_variance
        
        # Posterior Initialization (0 mean, Unit variance)
#         self.mu = np.zeros(self.n_features)
        self.mu = mu
        self.sigma_sq = np.ones(self.n_features) # Diagonal Covariance
        
        self.seen_mask = np.zeros(self.n_items, dtype=bool)

    def select_next_item_thompson(self):
        """
        Thompson Sampling (TS):
        Samples a realization of the user's preference vector from the current 
        posterior belief, then picks the item that maximizes the score for that sample.
        
        Complexity: O(N) - Just one matrix multiplication.
        """
        unseen_indices = np.where(~self.seen_mask)[0]
        if len(unseen_indices) == 0: return None
        
        X_unseen = self.X[unseen_indices]
        
        # 1. Sample a user vector from the posterior: w ~ N(mu, diag(sigma_sq))
        # Since covariance is diagonal, we sample each component independently.
        sample_w = np.random.normal(
            loc=self.mu, 
            scale=np.sqrt(self.sigma_sq)
        )
        
        # 2. Calculate scores for this sampled world view
        # Score = X * w_sampled
        sampled_scores = X_unseen @ sample_w
        
        # 3. Pick the best item
        best_local_idx = np.argmax(sampled_scores)
        return unseen_indices[best_local_idx]

    def select_next_item_ucb(self, alpha=2.0):
        """
        LinUCB (Upper Confidence Bound):
        Pick item with highest: Mean + alpha * Standard_Deviation
        
        Complexity: O(N) - Very fast vectorized operations.
        alpha: Exploration parameter (higher = more exploration).
        """
        unseen_indices = np.where(~self.seen_mask)[0]
        if len(unseen_indices) == 0: return None
        
        X_unseen = self.X[unseen_indices]
        
        # 1. Calculate Mean scores
        means = X_unseen @ self.mu
        
        # 2. Calculate Predictive Variance for all items
        # Var = x^T Sigma x. Since Sigma is diagonal: sum(x_ij^2 * sigma_j^2)
        # We can vectorize this: (X^2) @ sigma_sq
        # Note: We square X element-wise.
        pred_vars = (X_unseen**2) @ self.sigma_sq
        std_devs = np.sqrt(pred_vars)
        
        # 3. Calculate Upper Confidence Bound
        ucb_scores = means + alpha * std_devs
        
        best_local_idx = np.argmax(ucb_scores)
        return unseen_indices[best_local_idx]

    def update_belief(self, item_idx, feedback):
        """
        Bayesian Linear Regression Update (Diagonal Approximation)
        """
        x = self.X[item_idx]
        y = float(feedback)
        
        pred_mean = np.dot(x, self.mu)
        pred_var = np.dot(x**2, self.sigma_sq) + self.noise_var
        
        # Kalman Gain
        kalman_gain = (self.sigma_sq * x) / pred_var
        
        # Update Mean
        self.mu = self.mu + kalman_gain * (y - pred_mean)
        
        # Update Covariance (Diagonal Variational Approx)
        covariance_reduction = (self.sigma_sq * x)**2 / pred_var
        self.sigma_sq = np.maximum(self.sigma_sq - covariance_reduction, 1e-6)
        
        self.seen_mask[item_idx] = True

# %%
import numpy as np
from scipy import sparse

def get_latent_scaling_matrix(svd_model, use_sparse=True):
    """
    Creates the diagonal matrix Sigma from a fitted TruncatedSVD model.
    
    Args:
        svd_model: A fitted sklearn.decomposition.TruncatedSVD object.
        use_sparse (bool): If True, returns a scipy.sparse.dia_matrix. 
                           If False, returns a dense numpy array.
                           
    Returns:
        Sigma (matrix): A diagonal matrix of shape (n_components, n_components)
                        containing the singular values.
    """
    # The singular values (sigma)
    sigmas = svd_model.singular_values_
    n_components = len(sigmas)
    
    if use_sparse:
        # Create a sparse diagonal matrix
        return sparse.diags(sigmas, shape=(n_components, n_components))
    else:
        # Create a dense diagonal matrix
        return np.diag(sigmas)

def extract_item_embeddings(svd_model, scale_by_singular_values=True):
    """
    Extracts item embeddings correctly formatted for the Knowledge Gradient Recommender.
    
    Args:
        svd_model: Fitted SVD model (trained on User x Item matrix).
        scale_by_singular_values (bool): If True, weighs features by their importance.
        
    Returns:
        item_embeddings (np.ndarray): Shape (n_items, n_features)
    """
    # 1. Get the components (V^T) from SVD. Shape: (n_features, n_items)
    #    Note: In User-Item SVD, components_ corresponds to Items.
    raw_components = svd_model.components_
    
    if scale_by_singular_values:
        # Construct Sigma
        sigma_matrix = get_latent_scaling_matrix(svd_model, use_sparse=False)
        
        # Apply scaling: Sigma * V^T
        # We do this because we want the features to carry the weight of their variance.
        scaled_components = np.dot(sigma_matrix, raw_components)
        
        # Transpose to get (n_items, n_features) as required by the Recommender
        return scaled_components.T
    else:
        # Just transpose V^T -> V
        return raw_components.T

# %%
# use two items that you believe are similar to optimize the value of lambda_

a_name = find_match_using_terms(["sgeir", "7xUZ4069zcyBM4Bn10NQ1c"], cat2idx)
# a_name = find_match_using_terms(["7fNWySjsDn74LCawyJ27EQ"], cat2idx)

a = cat2idx[a_name]
print(f"{a_name=}")
print(f"Num Rows: {artist_mat[:, a].sum()}")

# a = cat2idx[find_match_using_terms(["Fleet Foxes"], cat2idx)]

# b = cat2idx[find_match_using_terms(["Fleet Foxes"], cat2idx)]
# b = cat2idx[find_match_using_terms(["Bon Iver", "4LEiUm1SRbFMgfqnQTwUbQ"], cat2idx)]
# b = cat2idx[find_match_using_terms(["SOHN"], cat2idx)]

# b_name = find_match_using_terms(["7fNWySjsDn74LCawyJ27EQ"], cat2idx)
b_name = find_match_using_terms(["Highas"], cat2idx)
b = cat2idx[b_name]
print(f"{b_name=}")
print(f"Num Rows: {artist_mat[:, b].sum()}")
# Out:
# a_name='Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)'
# Num Rows: 1981
# b_name='Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)'
# Num Rows: 412

# %%
n_items = mat.shape[1]

x = np.zeros(n_items, dtype=bool)
x[a] = True

y = svd.transform(x[None, :])[0]

# %%
from scipy import sparse
# Creates a sparse n x n identity matrix
matrix = sparse.eye(n_items, format='csr')

# %%
Y = svd.transform(matrix)

# %%
assert np.allclose(Y[a], y)

# %%
recommender = FastBayesianRecommender(Y, y)
    
print(f"Starting Optimal Exploration (KG) over {n_items} items.")
print("-------------------------------------------------------")

for step in range(100): # Ask 10 questions
    # Select best item to explore
    print(f"\nStep {step+1}: Calculating Knowledge Gradient...")
    item_idx = recommender.select_next_item_thompson()
    
    response = input(f"Do you like this: {idx2cat[item_idx]}").lower()
    
    assert "q" not in response
    
    assert "y" in response or "n" in response
    assert not ("y" in response and "n" in response)
    
    observed = "y" in response
    
    print("response:", observed)
    
    mu_old = recommender.mu
    recommender.update_belief(item_idx, observed)
    mu_new = recommender.mu
    
    print(f"diff: {np.linalg.norm(mu_old - mu_new)}")
#         if item_idx is None:
#             print("No more items to explore.")
#             break
            
#         # Simulate User Interaction
#         # (Replace this block with actual `input()` in production)
#         raw_score = np.dot(items[item_idx], true_user_pref)
#         prob = 1 / (1 + np.exp(-raw_score * 5)) # Sigmoid probability
#         observed = 1 if np.random.rand() < prob else 0
        
#         print(f"Recommender asks: Have you seen Item {item_idx}?")
#         print(f"User says: {'YES (Liked/Seen)' if observed else 'NO'}")
        
#         # Update model
#         recommender.update_belief(item_idx, observed)
# Out:
# Starting Optimal Exploration (KG) over 295860 items.
# -------------------------------------------------------
#
# Step 1: Calculating Knowledge Gradient...
# Do you like this: Ariana Grande (spotify:artist:66CXWjxzNUsdJxJ2JdwvnR)y
# response: True
# diff: 0.8194514915038598
#
# Step 2: Calculating Knowledge Gradient...
# Do you like this: Lil Wayne (spotify:artist:55Aa2cqylxrFIXC767Z865)n
# response: False
# diff: 0.0037393324260120574
#
# Step 3: Calculating Knowledge Gradient...
# Do you like this: Snoop Dogg (spotify:artist:7hJcb9fa4alzcOq3EaNPoG)n
# response: False
# diff: 0.010424923078926883
#
# Step 4: Calculating Knowledge Gradient...
# Do you like this: Bruno Mars (spotify:artist:0du5cEVh5yTK9QJze8zA0C)y
# response: True
# diff: 0.8039610861930375
#
# Step 5: Calculating Knowledge Gradient...
# Do you like this: Drake (spotify:artist:3TVXtAsR1Inumwj472S9r4)n
# response: False
# diff: 0.0013961366157815378
#
# Step 6: Calculating Knowledge Gradient...
# Do you like this: Childish Gambino (spotify:artist:73sIBHcqh3Z3NyqHKZ7FOL)n
# response: False
# diff: 0.004471788117077942
#
# Step 7: Calculating Knowledge Gradient...
# Do you like this: Mac Miller (spotify:artist:4LLpKhyESsyAXpc4laK94U)n
# response: False
# diff: 0.00979949645394982
#
# Step 8: Calculating Knowledge Gradient...
# Do you like this: Big Sean (spotify:artist:0c173mlxpT3dSFRgMO8XPh)n
# response: False
# diff: 0.0007172393963664403
#
# Step 9: Calculating Knowledge Gradient...
# Do you like this: OutKast (spotify:artist:1G9G7WwrXka3Z1r7aIDjI7)n
# response: False
# diff: 0.006465711803410044
#
# Step 10: Calculating Knowledge Gradient...
# Do you like this: Major Lazer (spotify:artist:738wLrAtLtCtFOLvQBXOXp)n
# response: False
# diff: 0.010700001551235691
#
# Step 11: Calculating Knowledge Gradient...
# Do you like this: Justin Timberlake (spotify:artist:31TPClRtHm23RisEBtV3X7)n
# response: False
# diff: 0.0033579675190489777
#
# Step 12: Calculating Knowledge Gradient...
# Do you like this: Justin Bieber (spotify:artist:1uNFoZAHBGtllmzznpCI3s)y
# response: True
# diff: 0.7947985624780919
#
# Step 13: Calculating Knowledge Gradient...
# Do you like this: Zedd (spotify:artist:2qxJFvFYMEDqd7ui6kSAcq)y
# response: True
# diff: 0.8411534269475293
#
# Step 14: Calculating Knowledge Gradient...
# Do you like this: French Montana (spotify:artist:6vXTefBL93Dj5IqAWq6OTv)n
# response: False
# diff: 0.0013183463089978986
#
# Step 15: Calculating Knowledge Gradient...
# Do you like this: Kygo (spotify:artist:23fqKkggKUBHNkbKtXEls4)n
# response: False
# diff: 0.04470627080115724
#
# Step 16: Calculating Knowledge Gradient...
# Do you like this: Chance The Rapper (spotify:artist:1anyVhU62p31KFi8MEzkbf)n
# response: False
# diff: 0.03587529300247821
#
# Step 17: Calculating Knowledge Gradient...
# Do you like this: Ellie Goulding (spotify:artist:0X2BH1fck6amBIoJhDVmmJ)n
# response: False
# diff: 0.024995732292574988
#
# Step 18: Calculating Knowledge Gradient...
# Do you like this: Eminem (spotify:artist:7dGJo4pcD2V6oG8kP0tJRR)n
# response: False
# diff: 0.0035169991384137902
#
# Step 19: Calculating Knowledge Gradient...
# Do you like this: Demi Lovato (spotify:artist:6S2OmqARrzebs0tKUEyXyp)n
# response: False
# diff: 0.012586483121733213
#
# Step 20: Calculating Knowledge Gradient...
# Do you like this: Adele (spotify:artist:4dpARuHxo51G3z768sgnrY)n
# response: False
# diff: 0.028037660234022824
#
# Step 21: Calculating Knowledge Gradient...
# Do you like this: DJ Snake (spotify:artist:540vIaP2JwjQb9dm3aArA4)n
# response: False
# diff: 0.019993643806045052
#
# Step 22: Calculating Knowledge Gradient...
# Do you like this: Kanye West (spotify:artist:5K4W6rqBFWDnAN6FQUkS6x)y
# response: True
# diff: 0.7838011055564738
#
# Step 23: Calculating Knowledge Gradient...
# Do you like this: DJ Khaled (spotify:artist:0QHgL1lAIqAw0HtD7YldmP)n
# response: False
# diff: 0.0031146690959310813
#
# Step 24: Calculating Knowledge Gradient...
# Do you like this: Future (spotify:artist:1RyvyyTE3xzB2ZywiAwp0i)n
# response: False
# diff: 0.010954360309589168
#
# Step 25: Calculating Knowledge Gradient...
# Do you like this: OneRepublic (spotify:artist:5Pwc4xIPtQLFEnJriah9YJ)n
# response: False
# diff: 0.0022404172849671885
#
# Step 26: Calculating Knowledge Gradient...
# Do you like this: Rae Sremmurd (spotify:artist:7iZtZyCzp3LItcw1wtPI3D)n
# response: False
# diff: 0.04359505809253151
#
# Step 27: Calculating Knowledge Gradient...
# Do you like this: Migos (spotify:artist:6oMuImdp5ZcFhWP0ESe6mG)n
# response: False
# diff: 0.029045060294532323
#
# Step 28: Calculating Knowledge Gradient...
# Do you like this: Selena Gomez (spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx)n
# response: False
# diff: 0.027253177332392988
#
# Step 29: Calculating Knowledge Gradient...
# Do you like this: Coldplay (spotify:artist:4gzpq5DPGxSnKTe4SA8HAU)y
# response: True
# diff: 0.7920339438004651
#
# Step 30: Calculating Knowledge Gradient...
# Do you like this: Rihanna (spotify:artist:5pKCCKE2ajJHZ9KAiaK11H)n
# response: False
# diff: 9.680451863443872e-05
#
# Step 31: Calculating Knowledge Gradient...
# Do you like this: Ed Sheeran (spotify:artist:6eUKZXaKkcviH0Ku9w2n3V)y
# response: True
# diff: 0.7698217847052209
#
# Step 32: Calculating Knowledge Gradient...
# Do you like this: David Guetta (spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai)y
# response: True
# diff: 0.8170815864235154
#
# Step 33: Calculating Knowledge Gradient...
# Do you like this: J. Cole (spotify:artist:6l3HvQ5sa6mXTsMTB19rO5)n
# response: False
# diff: 0.010379069829551715
#
# Step 34: Calculating Knowledge Gradient...
# Do you like this: Usher (spotify:artist:23zg3TcAtWQy7J6upgbUnj)n
# response: False
# diff: 0.011008717516764015
#
# Step 35: Calculating Knowledge Gradient...
# Do you like this: Hozier (spotify:artist:2FXC3k01G6Gw61bmprjgqS)y
# response: True
# diff: 0.8286251681221872
#
# Step 36: Calculating Knowledge Gradient...
# Do you like this: Sam Smith (spotify:artist:2wY79sveU1sp5g7SokKOiI)n
# response: False
# diff: 0.07923562327641938
#
# Step 37: Calculating Knowledge Gradient...
# Do you like this: Fifth Harmony (spotify:artist:1l8Fu6IkuTP0U5QetQJ5Xt)n
# response: False
# diff: 0.01958895280068599
#
# Step 38: Calculating Knowledge Gradient...
# Do you like this: Kendrick Lamar (spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg)n
# response: False
# diff: 0.01139968882239557
#
# Step 39: Calculating Knowledge Gradient...
# Do you like this: B.o.B (spotify:artist:5ndkK3dpZLKtBklKjxNQwT)n
# response: False
# diff: 0.022908199652346504
#
# Step 40: Calculating Knowledge Gradient...
# Do you like this: A$AP Rocky (spotify:artist:13ubrt8QOOCPljQ2FL1Kca)n
# response: False
# diff: 0.02649917251078825
#
# Step 41: Calculating Knowledge Gradient...
# Do you like this: Miley Cyrus (spotify:artist:5YGY8feqx7naU7z4HrwZM6)n
# response: False
# diff: 0.001805051633032937
#
# Step 42: Calculating Knowledge Gradient...
# Do you like this: Maroon 5 (spotify:artist:04gDigrS5kc9YWfZHwBETP)n
# response: False
# diff: 0.03398985239337197
#
# Step 43: Calculating Knowledge Gradient...
# Do you like this: One Direction (spotify:artist:4AK6F7OLvEQ5QYCBNiQWHq)n
# response: False
# diff: 0.024126040784728256
#
# Step 44: Calculating Knowledge Gradient...
# Do you like this: Lana Del Rey (spotify:artist:00FQb4jTyendYWaN8pK0wa)n
# response: False
# diff: 0.05293800223216628
#
# Step 45: Calculating Knowledge Gradient...
# Do you like this: Calvin Harris (spotify:artist:7CajNmpbOovFoOoasH2HaY)n
# response: False
# diff: 0.022826835530960606
#
# Step 46: Calculating Knowledge Gradient...
# Do you like this: Fetty Wap (spotify:artist:6PXS4YHDkKvl1wkIl4V8DL)n
# response: False
# diff: 0.01365776220672486
#
# Step 47: Calculating Knowledge Gradient...
# Do you like this: G-Eazy (spotify:artist:02kJSzxNuaWGqwubyUba0Z)n
# response: False
# diff: 0.015989165202432598
#
# Step 48: Calculating Knowledge Gradient...
# Do you like this: Chris Brown (spotify:artist:7bXgB6jMjp9ATFy66eO08Z)n
# response: False
# diff: 0.028700708540439237
#
# Step 49: Calculating Knowledge Gradient...
# Do you like this: The Chainsmokers (spotify:artist:69GGBxA162lTqCwzJG5jLp)n
# response: False
# diff: 0.014928450968639281
#
# Step 50: Calculating Knowledge Gradient...
# Do you like this: Lorde (spotify:artist:163tK9Wjr9P9DmM0AVK7lm)n
# response: False
# diff: 0.02886059374187116
#
# Step 51: Calculating Knowledge Gradient...
# Do you like this: Russ (spotify:artist:1z7b1Pr1rSlvWRzsW3HOrS)n
# response: False
# diff: 0.05192730260957498
#
# Step 52: Calculating Knowledge Gradient...
# Do you like this: Flume (spotify:artist:6nxWCVXbOlEVRexSbLsTer)n
# response: False
# diff: 0.020226334150142095
#
# Step 53: Calculating Knowledge Gradient...
# Do you like this: Michael Jackson (spotify:artist:3fMbdgg4jU18AjLCKBhRSm)y
# response: True
# diff: 0.8849633022678907
#
# Step 54: Calculating Knowledge Gradient...
# Do you like this: Sia (spotify:artist:5WUlDfRSoLAfcVSX1WnrxN)y
# response: True
# diff: 0.755803193351962
#
# Step 55: Calculating Knowledge Gradient...
# Do you like this: Jeremih (spotify:artist:3KV3p5EY4AvKxOlhGHORLg)n
# response: False
# diff: 0.009519895681427006
#
# Step 56: Calculating Knowledge Gradient...
# Do you like this: Frank Ocean (spotify:artist:2h93pZq0e7k5yf4dywlkpM)n
# response: False
# diff: 0.03802874796104245
#
# Step 57: Calculating Knowledge Gradient...
# Do you like this: Jason Derulo (spotify:artist:07YZf4WDAMNwqr4jfgOZ8y)n
# response: False
# diff: 0.07192795225342176
#
# Step 58: Calculating Knowledge Gradient...
# Do you like this: The Notorious B.I.G. (spotify:artist:5me0Irg2ANcsgc93uaYrpb)n
# response: False
# diff: 0.03405953816211022
#
# Step 59: Calculating Knowledge Gradient...
# Do you like this: Macklemore & Ryan Lewis (spotify:artist:5BcAKTbp20cv7tC5VqPFoC)n
# response: False
# diff: 0.026612916401403452
#
# Step 60: Calculating Knowledge Gradient...
# Do you like this: Beyoncé (spotify:artist:6vWDO969PvNqNYHIOW5v0m)n
# response: False
# diff: 0.03414343560581239
#
# Step 61: Calculating Knowledge Gradient...
# Do you like this: Pitbull (spotify:artist:0TnOYISbd1XYRBk9myaseg)n
# response: False
# diff: 0.08191704666522186
#
# Step 62: Calculating Knowledge Gradient...
# Do you like this: JAY Z (spotify:artist:3nFkdlSjzX9mRTtwJOzDYB)n
# response: False
# diff: 0.024217413000436713
#
# Step 63: Calculating Knowledge Gradient...
# Do you like this: Alessia Cara (spotify:artist:2wUjUUtkb5lvLKcGKsKqsR)n
# response: False
# diff: 0.11246628723400214
#
# Step 64: Calculating Knowledge Gradient...
# Do you like this: KYLE (spotify:artist:4qBgvVog0wzW75IQ48mU7v)n
# response: False
# diff: 0.0012515933063969049
#
# Step 65: Calculating Knowledge Gradient...
# Do you like this: Vance Joy (spotify:artist:10exVja0key0uqUkk6LJRT)y
# response: True
# diff: 0.7697809552302899
#
# Step 66: Calculating Knowledge Gradient...
# Do you like this: John Mayer (spotify:artist:0hEurMDQu99nJRq8pTxO14)y
# response: True
# diff: 0.7136414249481091
#
# Step 67: Calculating Knowledge Gradient...
# Do you like this: Twenty One Pilots (spotify:artist:3YQKmKGau1PzlVlkL1iodx)n
# response: False
# diff: 0.00991948081976142
#
# Step 68: Calculating Knowledge Gradient...
# Do you like this: Desiigner (spotify:artist:7pFeBzX627ff0VnN6bxPR4)n
# response: False
# diff: 0.05041674883772593
#
# Step 69: Calculating Knowledge Gradient...
# Do you like this: Avicii (spotify:artist:1vCWHaC5f2uS3yhpwWbIA6)y
# response: True
# diff: 0.915975474680304
#
# Step 70: Calculating Knowledge Gradient...
# Do you like this: Wiz Khalifa (spotify:artist:137W8MRPWKqSmrBGDBFSop)n
# response: False
# diff: 0.020521728964200132
#
# Step 71: Calculating Knowledge Gradient...
# Do you like this: The Weeknd (spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ)n
# response: False
# diff: 0.00017524905201617963
#
# Step 72: Calculating Knowledge Gradient...
# Do you like this: Katy Perry (spotify:artist:6jJ0s89eD6GaHleKKya26X)n
# response: False
# diff: 0.008905980965896641
#
# Step 73: Calculating Knowledge Gradient...
# Do you like this: The Beatles (spotify:artist:3WrFJ7ztbogyGnTHbHJFl2)y
# response: True
# diff: 0.6854791407183548
#
# Step 74: Calculating Knowledge Gradient...
# Do you like this: Flo Rida (spotify:artist:0jnsk9HBra6NMjO2oANoPY)n
# response: False
# diff: 0.08198601988636126
#
# Step 75: Calculating Knowledge Gradient...
# Do you like this: blackbear (spotify:artist:2cFrymmkijnjDg9SS92EPM)n
# response: False
# diff: 0.005783589325354701
#
# Step 76: Calculating Knowledge Gradient...
# Do you like this: Imagine Dragons (spotify:artist:53XhwfbYqKCa1cC15pYq2q)y
# response: True
# diff: 0.7379144084237875
#
# Step 77: Calculating Knowledge Gradient...
# Do you like this: Halsey (spotify:artist:26VFTg2z8YR0cCuwLzESi2)n
# response: False
# diff: 0.15757196427886483
#
# Step 78: Calculating Knowledge Gradient...
# Do you like this: Shawn Mendes (spotify:artist:7n2wHs1TKAczGzO7Dd2rGr)n
# response: False
# diff: 0.02892385702832639
#
# Step 79: Calculating Knowledge Gradient...
# Do you like this: Logic (spotify:artist:4xRYI6VqpkE3UwrDrAZL8L)n
# response: False
# diff: 0.025152212867840945
#
# Step 80: Calculating Knowledge Gradient...
# Do you like this: Post Malone (spotify:artist:246dkjvS1zLTtiykXe5h60)n
# response: False
# diff: 0.06690767831780912
#
# Step 81: Calculating Knowledge Gradient...
# Do you like this: Khalid (spotify:artist:6LuN9FCkKOj5PcnpouEgny)n
# response: False
# diff: 0.1458256862859344
#
# Step 82: Calculating Knowledge Gradient...
# Do you like this: The Killers (spotify:artist:0C0XlULifJtAgn6ZNCW2eu)n
# response: False
# diff: 0.03665128301985942
#
# Step 83: Calculating Knowledge Gradient...
# Do you like this: The Lumineers (spotify:artist:16oZKvXb6WkQlVAjwo2Wbg)y
# response: True
# diff: 0.7397355987850297
#
# Step 84: Calculating Knowledge Gradient...
# Do you like this: Tove Lo (spotify:artist:4NHQUGzhtTLFvgF5SZesLK)n
# response: False
# diff: 0.029050251058529403
#
# Step 85: Calculating Knowledge Gradient...
# Do you like this: 2 Chainz (spotify:artist:17lzZA2AlOHwCwFALHttmp)n
# response: False
# diff: 0.023607166613212285
#
# Step 86: Calculating Knowledge Gradient...
# Do you like this: The Head and the Heart (spotify:artist:0n94vC3S9c3mb2HyNAOcjg)n
# response: False
# diff: 0.08688615760987986
#
# Step 87: Calculating Knowledge Gradient...
# Do you like this: Nicki Minaj (spotify:artist:0hCNtLu0JehylgoiP8L4Gh)n
# response: False
# diff: 0.00131986481252242
#
# Step 88: Calculating Knowledge Gradient...
# Do you like this: Trey Songz (spotify:artist:2iojnBLj0qIMiKPvVhLnsH)n
# response: False
# diff: 0.07692995411441382
#
# Step 89: Calculating Knowledge Gradient...
# Do you like this: Martin Garrix (spotify:artist:60d24wfXkVzDSfLS6hyCjZ)n
# response: False
# diff: 0.0520651753691126
#
# Step 90: Calculating Knowledge Gradient...
# Do you like this: Britney Spears (spotify:artist:26dSoYclwsYLMAKD3tpOr4)n
# response: False
# diff: 0.0035447013745375996
#
# Step 91: Calculating Knowledge Gradient...
# Do you like this: DRAM (spotify:artist:5M0lbkGluOPXLeFjApw8r8)n
# response: False
# diff: 0.03885413420403145
#
# Step 92: Calculating Knowledge Gradient...
# Do you like this: Charlie Puth (spotify:artist:6VuMaDnrHyPL1p4EHjYLi7)n
# response: False
# diff: 0.04170408776747773
#
# Step 93: Calculating Knowledge Gradient...
# Do you like this: John Legend (spotify:artist:5y2Xq6xcjJb2jVM54GHK3t)n
# response: False
# diff: 0.06294538710975263
#
# Step 94: Calculating Knowledge Gradient...
# Do you like this: Bastille (spotify:artist:7EQ0qTo7fWT7DPxmxtSYEc)n
# response: False
# diff: 0.07047587816484878
#
# Step 95: Calculating Knowledge Gradient...
# Do you like this: Red Hot Chili Peppers (spotify:artist:0L8ExT028jH3ddEcZwqJJ5)n
# response: False
# diff: 0.02858839225642718
#
# Step 96: Calculating Knowledge Gradient...
# Do you like this: Mike Posner (spotify:artist:2KsP6tYLJlTBvSUxnwlVWa)n
# response: False
# diff: 0.06855939408312693
#
# Step 97: Calculating Knowledge Gradient...
# Do you like this: Journey (spotify:artist:0rvjqX7ttXeg3mTy8Xscbt)y
# response: True
# diff: 0.6766063820042219
#
# Step 98: Calculating Knowledge Gradient...
# Do you like this: Jack Johnson (spotify:artist:3GBPw9NK25X1Wt2OUvOwY3)n
# response: False
# diff: 0.24102935632745873
#
# Step 99: Calculating Knowledge Gradient...
# Do you like this: Panic! At The Disco (spotify:artist:20JZFwl6HVl6yg8a4H3ZqK)y
# response: True
# diff: 0.786935917731044
#
# Step 100: Calculating Knowledge Gradient...
# Do you like this: Lil Uzi Vert (spotify:artist:4O15NlyKLIASxsJ0PrXPfz)n
# response: False
# diff: 0.07749132918137962

# %%
recommender = FastBayesianRecommender(Y, y, noise_variance=0)
    
print(f"Starting Optimal Exploration (KG) over {n_items} items.")
print("-------------------------------------------------------")

for step in range(100): # Ask 10 questions
    # Select best item to explore
    print(f"\nStep {step+1}: Calculating Knowledge Gradient...")
    item_idx = recommender.select_next_item_thompson()
    
    response = input(f"Do you like this: {idx2cat[item_idx]}").lower()
    
    assert "q" not in response
    
    assert "y" in response or "n" in response
    assert not ("y" in response and "n" in response)
    
    observed = "y" in response
    
    print("response:", observed)
    
    mu_old = recommender.mu
    recommender.update_belief(item_idx, observed)
    mu_new = recommender.mu
    
    print(f"diff: {np.linalg.norm(mu_old - mu_new)}")
#         if item_idx is None:
#             print("No more items to explore.")
#             break
            
#         # Simulate User Interaction
#         # (Replace this block with actual `input()` in production)
#         raw_score = np.dot(items[item_idx], true_user_pref)
#         prob = 1 / (1 + np.exp(-raw_score * 5)) # Sigmoid probability
#         observed = 1 if np.random.rand() < prob else 0
        
#         print(f"Recommender asks: Have you seen Item {item_idx}?")
#         print(f"User says: {'YES (Liked/Seen)' if observed else 'NO'}")
        
#         # Update model
#         recommender.update_belief(item_idx, observed)
# Out:
# Starting Optimal Exploration (KG) over 295860 items.
# -------------------------------------------------------
#
# Step 1: Calculating Knowledge Gradient...
# Do you like this: Lana Del Rey (spotify:artist:00FQb4jTyendYWaN8pK0wa)n
# response: False
# diff: 0.0016355896343865925
#
# Step 2: Calculating Knowledge Gradient...
# Do you like this: B.o.B (spotify:artist:5ndkK3dpZLKtBklKjxNQwT)y
# response: True
# diff: 1.127437653421191
#
# Step 3: Calculating Knowledge Gradient...
# Do you like this: Kendrick Lamar (spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg)n
# response: False
# diff: 0.008837575782388928
#
# Step 4: Calculating Knowledge Gradient...
# Do you like this: Katy Perry (spotify:artist:6jJ0s89eD6GaHleKKya26X)y
# response: True
# diff: 1.1112901659744965
#
# Step 5: Calculating Knowledge Gradient...
# Do you like this: Nicki Minaj (spotify:artist:0hCNtLu0JehylgoiP8L4Gh)q
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[42], line 13
#       9 item_idx = recommender.select_next_item_thompson()
#      11 response = input(f"Do you like this: {idx2cat[item_idx]}").lower()
# ---> 13 assert "q" not in response
#      15 assert "y" in response or "n" in response
#      16 assert not ("y" in response and "n" in response)
#
# AssertionError:

# %%
# Y_alt = extract_item_embeddings(svd)
Y_alt = Y[:, :32]

y_alt = Y_alt[a]

# %%
best = np.argsort(np.linalg.norm(Y_alt - y_alt[None, :], axis=-1))
# best = np.argsort(np.linalg.norm(Y - y[None, :], axis=-1))
# best = np.argsort(-svd.inverse_transform(recommender.mu[None, :])[0])

top_k = 100

for i in best[:top_k]:
    print(idx2cat[i])
# Out:
# Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)
# PHOX (spotify:artist:3ix4iw2URncSdE7X292bXy
# Emilíana Torrini (spotify:artist:08j69Ndyx1P7RLO3Janb5P)
# Bonjah (spotify:artist:3SGCwaCfLxx2axpPq9J5LC)
# Luke Sital-Singh (spotify:artist:3Lw97gGh8bp1MftsYmwJHG)
# Dry the River (spotify:artist:5VIq5RHAbVUMF700vdwfYw)
# The Dø (spotify:artist:2mcNCn1qbZUQ3J9KHapUxj)
# Vetiver (spotify:artist:7ACSlU8kTcQIbvpwLWze8E)
# Horse Feathers (spotify:artist:0lO2c86rQmrRJArBxgw0v8)
# Overcoats (spotify:artist:2pst3pDewxsl4kJERuDZpp)
# Atlas Bound (spotify:artist:6107PIkQDuEUcdpZqSzQsu)
# Tobias Jesso Jr. (spotify:artist:3RosuARXNIOfNYoJXR7fzA)
# John Vincent III (spotify:artist:1sgVcCMCarG7yWGmkP9wMb)
# Tash Sultana (spotify:artist:6zVFRTB0Y1whWyH7ZNmywf)
# Alice Boman (spotify:artist:3WiytRnvoL0kT3oAGl9TCt)
# The Cave Singers (spotify:artist:4SjCvf9Ctuz369ZKAnjkZP)
# Zee Avi (spotify:artist:6zGcYBjlNOMSVVrl7ZoGsH)
# St. South (spotify:artist:1n3X60xWCyL1zytSiKeu4D)
# How To Dress Well (spotify:artist:4jLcgJjDGmW0HmvbSf6lEI)
# Ludovico Einaudi (spotify:artist:2uFUBdaVGtyMqckSeCl0Qj)

# %%
idx2cat[item_idx]
# Out:
# 'Rihanna (spotify:artist:5pKCCKE2ajJHZ9KAiaK11H)'

# %%
from tqdm.auto import tqdm
from sklearn.metrics import roc_curve, roc_auc_score

np.random.seed(42)

I = np.random.choice(mat.shape[0], size=128)
y_true = np.asarray(mat[I, :].todense(), dtype="bool")

errs = []
err_trues = []
err_falses = []
n_components_to_use = [1, 2, 4, 8, 16, 32, 64, 128]

roc_scores = []

for components_to_use in tqdm(n_components_to_use):
    x = np.copy(X[I])
    
    assert components_to_use >= 1
    assert components_to_use <= 128

    x[:, components_to_use:] = 0

    y = svd.inverse_transform(x)
    y = y >= .5
    
    err = 1 - (y == y_true).mean()
    err_true = 1 - (y[y_true] == y_true[y_true]).mean()
    err_false = 1 - (y[~y_true] == y_true[~y_true]).mean()

    errs.append(err)
    err_trues.append(err_true)
    err_falses.append(err_false)
    
    roc_scores.append(roc_auc_score(np.reshape(y_true, -1), np.reshape(y, -1)))
    
#     print((y[y_true] == y_true[y_true]).mean())
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
errs = np.array(errs)
err_trues = np.array(err_trues)
err_falses = np.array(err_falses)
roc_scores = np.array(roc_scores)

# %%
import matplotlib.pyplot as plt

plt.plot(n_components_to_use, roc_scores);

# %%
err_trues[-1]
# Out:
# np.float64(0.7390438247011952)

# %%
import matplotlib.pyplot as plt

plt.plot(n_components_to_use, 1 - err_trues);

# %%
import matplotlib.pyplot as plt

plt.plot(n_components_to_use, 1 - err_trues);

# %%
# plt.plot(n_components_to_use, np.log(errs));
plt.plot(n_components_to_use, np.log(err_trues));
# plt.plot(n_components_to_use, np.log(err_falses));

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_auc_score()

# %%
np.log(1 - .99)
# Out:
# np.float64(-4.605170185988091)

# %%
(y == y_true).mean()
# Out:
# np.float64(0.999875941323599)

# %%
(y == y_true).mean()
# Out:
# np.float64(0.9999054620428581)

# %%
(y[y_true] == y_true[y_true]).mean()
# Out:
# np.float64(0.2660846460428924)

# %%
(y[~y_true] == y_true[~y_true]).mean()
# Out:
# np.float64(0.9999969542610154)

# %%
# %%time

svd = TruncatedSVD(8)

X3 = svd.fit_transform(X2)
# Out:
# CPU times: total: 9.09 s
# Wall time: 9.12 s

# %%
# %%time

svd = TruncatedSVD(16)

X3 = svd.fit_transform(X2)
# Out:
# CPU times: total: 11 s
# Wall time: 11.1 s

# %%
# %%time

svd = TruncatedSVD(32)

X3 = svd.fit_transform(X2)
# Out:
# CPU times: total: 16.4 s
# Wall time: 15.3 s

# %%
# %%time

svd = TruncatedSVD(64)

X3 = svd.fit_transform(X2)
# Out:
# CPU times: total: 26.9 s
# Wall time: 23.9 s

# %%
# %%time

svd = TruncatedSVD(128)

X3 = svd.fit_transform(X2)
# Out:
# CPU times: total: 52.9 s
# Wall time: 45.9 s

# %%
# %%time

from scipy.sparse.linalg import svds

embedding_dim = 128

u, s, vt = svds(X2, k=embedding_dim)
# Out:
# CPU times: total: 2min 13s
# Wall time: 2min 12s

# %%
# def get_spectral_ease_embeddings(G_sparse, embedding_dim=64, lambda_reg=500.0):
#     """
#     Approximates EASE embeddings using re-weighted SVD.
#     This is extremely fast and scalable.
#     """
#     from scipy.sparse.linalg import svds
    
#     # 1. Standard SVD on the Gram Matrix (Covariance)
#     # u: eigenvectors (item embeddings directions)
#     # s: singular values (variance/popularity)
#     u, s, vt = svds(G_sparse, k=embedding_dim)
    
#     # 2. The "EASE Transformation"
#     # In standard SVD, embeddings are u * sqrt(s).
#     # In EASE, we want to suppress high variance (popularity).
#     # The spectral filter of EASE is roughly 1 / (s + lambda).
    
#     # We re-weight the singular values:
#     # Instead of emphasizing top components, we flatten them based on lambda.
#     # This creates embeddings that are "whitened" relative to popularity.
    
#     weights = s / (s + lambda_reg)
    
#     # 3. Create Embeddings
#     # This creates a low-rank approximation of the EASE weight matrix
#     ease_embeddings = u * weights[None, :]
    
#     return ease_embeddings

# %%
def get_spectral_ease_embeddings(u, s, vt, lambda_reg=500.0):
    """
    Approximates EASE embeddings using re-weighted SVD.
    This is extremely fast and scalable.
    """
    
    # 2. The "EASE Transformation"
    # In standard SVD, embeddings are u * sqrt(s).
    # In EASE, we want to suppress high variance (popularity).
    # The spectral filter of EASE is roughly 1 / (s + lambda).
    
    # We re-weight the singular values:
    # Instead of emphasizing top components, we flatten them based on lambda.
    # This creates embeddings that are "whitened" relative to popularity.
    
    weights = s / (s + lambda_reg)
    
    # 3. Create Embeddings
    # This creates a low-rank approximation of the EASE weight matrix
    ease_embeddings = u * weights[None, :]
#     ease_embeddings = u * np.sqrt(weights)[None, :]
    
    return ease_embeddings

# %%
components_to_use = 128

ease_embeddings = get_spectral_ease_embeddings(u[:, :components_to_use], s[:components_to_use], vt, lambda_reg=1000000)

Y_alt = ease_embeddings
y_alt = ease_embeddings[keep_inds.tolist().index(a)]

best = keep_inds[np.argsort(np.linalg.norm(Y_alt - y_alt[None, :], axis=-1))]
# best = np.argsort(np.linalg.norm(Y - y[None, :], axis=-1))
# best = np.argsort(-svd.inverse_transform(recommender.mu[None, :])[0])

top_k = 100

for i in best[:top_k]:
    print(idx2cat[i])
# Out:
# Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)
# PHOX (spotify:artist:3ix4iw2URncSdE7X292bXy)
# Night Beds (spotify:artist:533wKOfkJylNSi6ntO1wXd)
# On An On (spotify:artist:3Topzt1UZCz8GQlP7Zsu0M)
# Typhoon (spotify:artist:6p6WlxIkeWH8yOYvciFfVl)
# Motopony (spotify:artist:5urVI6ZUTzPlsqQoHVwc9s)
# San Fermin (spotify:artist:7fSnislKgW9Mz0YIqWQmGt)
# Cathedrals (spotify:artist:7HIjKw4rHS0MtmV0cqSlpB)
# Junip (spotify:artist:7HcipAIJatVGT4U6HQrnFW)
# Wake Owl (spotify:artist:2lnn5H36McBxbyhPYg10oj)
# Patrick Watson (spotify:artist:7bPs6jf983f0bjRAt1yxDM)
# Little Green Cars (spotify:artist:2Vz3AN2wY3xjS2jCaGMVsy)
# Stateless (spotify:artist:6msJKphD3VXZPItnztefdH)
# Houses (spotify:artist:648kpaANsUr1HABoE4mkPw)
# Nick Mulvey (spotify:artist:3x8FbPjh2Qz55XMdE2Yalj)
# Active Child (spotify:artist:54KTsBl98buzGkELjGlnuU)
# Majical Cloudz (spotify:artist:4BEYBN6NCPrFk3sOLMTby3)
# Wye Oak (spotify:artist:5SjNVG3L9mgWQPsfp1sFDB)
# Wildcat! Wildcat! (spotify:artist:75idpsM55NDCel7H06QwKO)
# Conner Youngblood (spotify:artist:1HzpwUIkmmlGCNuoOcXiIW)
# Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO)
# Vancouver Sleep Clinic (spotify:artist:77BznF1Dr1k5KyEZ6Nn3jB)
# Hamilton Leithauser + Rostam (spotify:artist:3h0w83PsjASrm5999trG4n)
# Tom Rosenthal (spotify:artist:1AgxgADPuRIW1wyaA4OKcB)
# BOY (spotify:artist:7I7ObCLzhAnOchc4fCQiRX)
# Son Little (spotify:artist:4lujUKeO6nQAJXpq37Epn7)
# Fink (spotify:artist:2t9yJDJIEtvPmr2iRIdqBf)
# The Apache Relay (spotify:artist:62pBNClOEZJEyRXrzC2CtI)
# Laura Marling (spotify:artist:7B2edU3Q7btJoNsoHCNohM)
# St. South (spotify:artist:1n3X60xWCyL1zytSiKeu4D)
# S. Carey (spotify:artist:2LSJrlndCuTpdEluvYHc2E)
# Sarah Jaffe (spotify:artist:1z2SrszsRmq47kDhBAnyNS)
# Bahari (spotify:artist:0fs8oBR1rx7JIXZi75h7Uu)
# Sjowgren (spotify:artist:32Ko3nL0210QAt14S3Rs4Y)
# Alex Ebert (spotify:artist:1me05HW5s7TShHra5nN7uE)
# Perfume Genius (spotify:artist:2ueoLVCXQ948OfhVvAy3Nn)
# Slow Club (spotify:artist:75Kh0eqgzo9f43Dan1JzSV)
# Freedom Fry (spotify:artist:195hFqaTDENqLCcG8uGtM7)
# The Antlers (spotify:artist:5o8Wylae9k23IEJMIiwd8s)
# The Dodos (spotify:artist:10tysauSA5JATqniBDu2Ed)
# Cœur De Pirate (spotify:artist:2eRNMtoi82UZUuaL6naDjA)
# Elliot Root (spotify:artist:2czQ8vG4i3wBWxfsAt4yqw)
# Big Scary (spotify:artist:4mLYW48jy9Pwv6KpT74Evf)
# Savoir Adore (spotify:artist:2weMnYqCmtNUrSLAJq5dD8)
# How To Dress Well (spotify:artist:4jLcgJjDGmW0HmvbSf6lEI)
# Tash Sultana (spotify:artist:6zVFRTB0Y1whWyH7ZNmywf)
# Snakadaktal (spotify:artist:0SdEkx5Ai2gl0W7pnhlsfy)
# Alpine (spotify:artist:4tKUoNubW02udXOh7SLtXV)
# You Won't (spotify:artist:5lBYzBQdFqhcJRc30cPHa9)
# Mighty Oaks (spotify:artist:5AVJt6VYXT4hMRP8D3MRAC)
# Ciaran Lavery (spotify:artist:7zOuMHqRJ6YOMnCGpLfuTU)
# The Preatures (spotify:artist:5gcDZA9xXCOspWgQilUYIu)
# Julia Stone (spotify:artist:4gZRt9wlRx1IsxT9glJdrc)
# Prinze George (spotify:artist:3o6TKTQIu0lCYcNtSO3i1G)
# Punch Brothers (spotify:artist:4gFssfOmWNY3LfIZ3zyoy4)
# Caught A Ghost (spotify:artist:2e898fil1F5umrc2LBtV93)
# Ben Sollee (spotify:artist:3Zzs4IqjV4b0yEFWqRv1si)
# Zee Avi (spotify:artist:6zGcYBjlNOMSVVrl7ZoGsH)
# Whitley (spotify:artist:17C909ZAaDFHCNLhsqsb25)
# Absofacto (spotify:artist:7gAYvcQFmAruyvwGjxrSUr)

# %%
from scipy.sparse.linalg import factorized, spsolve
import scipy.sparse as sp

def calculate_ease_exact_sparse_solver(G_sparse, lambda_reg=500.0, threshold=1e-4):
    """
    Uses sparse Cholesky/LU to solve exact weights.
    Returns a SPARSE matrix by pruning small values.
    """
    N = G_sparse.shape[0]
    
    # 1. Setup Linear System (A = G + lambda * I)
    # CSC format is often better for arithmetic/inversion
    A = G_sparse + sp.eye(N) * lambda_reg
    A = A.tocsc() 
    
    # 2. Factorize A (Pre-compute the solver)
    # This utilizes the sparsity of A to speed up the solve
    solve_A = factorized(A)
    
    # 3. Solve for P column-by-column (or batch)
    # We solve A * P = I. 
    # To save memory, we don't create full I. We solve for unit vectors.
    
    # NOTE: If N is huge, you cannot hold the result in memory.
    # We will build B iteratively.
    
    row_indices = []
    col_indices = []
    data_values = []
    
    # We need the diagonal of P first to normalize. 
    # Unfortunately, getting the exact diagonal requires solving for all columns 
    # or using advanced estimation. 
    # For 'Exact', we solve all columns.
    
    # This loop is slow in Python. In production, C++ or batched solving is preferred.
    for i in range(N):
        # Create standard basis vector e_i
        e_i = np.zeros(N)
        e_i[i] = 1.0
        
        # Solve A * p_col = e_i
        p_col = solve_A(e_i)
        
        # We need P_ii for normalization
        P_ii = p_col[i]
        
        # Calculate B column i: B_ji = - P_ji / P_ii
        # We process the dense column p_col into sparse format immediately
        
        # Normalize
        b_col = - p_col / P_ii
        b_col[i] = 0.0 # Constraint diag(B) = 0
        
        # Thresholding: Only keep significant weights
        mask = np.abs(b_col) > threshold
        
        # Store indices
        idx = np.where(mask)[0]
        row_indices.extend(idx)
        col_indices.extend([i] * len(idx))
        data_values.extend(b_col[idx])

    # Reconstruct Sparse B
    B_sparse = sp.csc_matrix((data_values, (row_indices, col_indices)), shape=(N, N))
    return B_sparse

# %%
# %%time

B_sparse = calculate_ease_exact_sparse_solver(X2)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File <timed exec>:1
#
# Cell In[109], line 18, in calculate_ease_exact_sparse_solver(G_sparse, lambda_reg, threshold)
#      14 A = A.tocsc()
#      16 # 2. Factorize A (Pre-compute the solver)
#      17 # This utilizes the sparsity of A to speed up the solve
# ---> 18 solve_A = factorized(A)
#      20 # 3. Solve for P column-by-column (or batch)
#      21 # We solve A * P = I.
#      22 # To save memory, we don't create full I. We solve for unit vectors.
#      23
#      24 # NOTE: If N is huge, you cannot hold the result in memory.
#      25 # We will build B iteratively.
#      27 row_indices = []
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\linalg\_dsolve\linsolve.py:597, in factorized(A)
#     595     return solve
#     596 else:
# --> 597     return splu(A).solve
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\linalg\_dsolve\linsolve.py:428, in splu(A, permc_spec, diag_pivot_thresh, relax, panel_size, options)
#     425 if (_options["ColPerm"] == "NATURAL"):
#     426     _options["SymmetricMode"] = True
# --> 428 return _superlu.gstrf(N, A.nnz, A.data, indices, indptr,
#     429                       csc_construct_func=csc_construct_func,
#     430                       ilu=False, options=_options)
#
# MemoryError:

# %%
# %%time

svd = TruncatedSVD(256)

X3 = svd.fit_transform(X2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\nsvd = TruncatedSVD(256)\n\nX3 = svd.fit_transform(X2)\n')
#
# File ~\miniconda3\envs\recsys\lib\site-packages\IPython\core\interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2541 with self.builtin_trap:
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
#    2545 # The code below prevents the output from being displayed
#    2546 # when using magics with decorator @output_can_be_silenced
#    2547 # when the last Python token in the expression is a ';'.
#    2548 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\miniconda3\envs\recsys\lib\site-packages\IPython\core\magics\execution.py:1370, in ExecutionMagics.time(self, line, cell, local_ns)
#    1368 st = clock2()
#    1369 try:
# -> 1370     exec(code, glob, local_ns)
#    1371     out = None
#    1372     # multi-line %%time case
#
# File <timed exec>:3
#
# File ~\miniconda3\envs\recsys\lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\miniconda3\envs\recsys\lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\miniconda3\envs\recsys\lib\site-packages\sklearn\decomposition\_truncated_svd.py:244, in TruncatedSVD.fit_transform(self, X, y)
#     239     if self.n_components > X.shape[1]:
#     240         raise ValueError(
#     241             f"n_components({self.n_components}) must be <="
#     242             f" n_features({X.shape[1]})."
#     243         )
# --> 244     U, Sigma, VT = _randomized_svd(
#     245         X,
#     246         self.n_components,
#     247         n_iter=self.n_iter,
#     248         n_oversamples=self.n_oversamples,
#     249         power_iteration_normalizer=self.power_iteration_normalizer,
#     250         random_state=random_state,
#     251         flip_sign=False,
#     252     )
#     253     U, VT = svd_flip(U, VT, u_based_decision=False)
#     255 self.components_ = VT
#
# File ~\miniconda3\envs\recsys\lib\site-packages\sklearn\utils\extmath.py:568, in _randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state, svd_lapack_driver)
#     564 if transpose:
#     565     # this implementation is a bit faster with smaller shape[1]
#     566     M = M.T
# --> 568 Q = _randomized_range_finder(
#     569     M,
#     570     size=n_random,
#     571     n_iter=n_iter,
#     572     power_iteration_normalizer=power_iteration_normalizer,
#     573     random_state=random_state,
#     574 )
#     576 # project M to the (k + p) dimensional space using the basis vectors
#     577 B = Q.T @ M
#
# File ~\miniconda3\envs\recsys\lib\site-packages\sklearn\utils\extmath.py:350, in _randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     347 # Perform power iterations with Q to further 'imprint' the top
#     348 # singular vectors of A in Q
#     349 for _ in range(n_iter):
# --> 350     Q, _ = normalizer(A @ Q)
#     351     Q, _ = normalizer(A.T @ Q)
#     353 # Sample the range of A using by linear projection of Q
#     354 # Extract an orthonormal basis
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\_base.py:732, in _spbase.__matmul__(self, other)
#     729 if isscalarlike(other):
#     730     raise ValueError("Scalar operands are not allowed, "
#     731                      "use '*' instead")
# --> 732 return self._matmul_dispatch(other)
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\_base.py:624, in _spbase._matmul_dispatch(self, other)
#     622         return result.reshape(M, 1)
#     623     elif other.ndim == 2 and other.shape[0] == N:
# --> 624         return self._matmul_multivector(other)
#     626 if isscalarlike(other):
#     627     # scalar value
#     628     return self._mul_scalar(other)
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\_compressed.py:539, in _cs_matrix._matmul_multivector(self, other)
#     537 # csr_matvecs or csc_matvecs
#     538 fn = getattr(_sparsetools, self.format + '_matvecs')
# --> 539 fn(M, N, n_vecs, self.indptr, self.indices, self.data,
#     540    other.ravel(), result.ravel())
#     542 if self.ndim == 1:
#     543     return result.reshape((n_vecs,))
#
# KeyboardInterrupt:

# %%
# %%time

svd = TruncatedSVD(1)

X3 = svd.fit_transform(X)
# Out:
# CPU times: total: 27.7 s
# Wall time: 27.8 s

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.sort(counts))

# %%
(counts >= 128).mean()
# Out:
# np.float64(0.05848374231055229)

# %%
# %%time

svd = TruncatedSVD(128)

X2 = svd.fit_transform(X)

# %%
X2.shape

# %%
# use two items that you believe are similar to optimize the value of lambda_

a_name = find_match_using_terms(["sgeir", "7xUZ4069zcyBM4Bn10NQ1c"], cat2idx)
# a_name = find_match_using_terms(["7fNWySjsDn74LCawyJ27EQ"], cat2idx)

a = cat2idx[a_name]
print(f"{a_name=}")
print(f"Num Rows: {artist_mat[:, a].sum()}")

# a = cat2idx[find_match_using_terms(["Fleet Foxes"], cat2idx)]

# b = cat2idx[find_match_using_terms(["Fleet Foxes"], cat2idx)]
# b = cat2idx[find_match_using_terms(["Bon Iver", "4LEiUm1SRbFMgfqnQTwUbQ"], cat2idx)]
# b = cat2idx[find_match_using_terms(["SOHN"], cat2idx)]

# b_name = find_match_using_terms(["7fNWySjsDn74LCawyJ27EQ"], cat2idx)
b_name = find_match_using_terms(["Highas"], cat2idx)
b = cat2idx[b_name]
print(f"{b_name=}")
print(f"Num Rows: {artist_mat[:, b].sum()}")
# Out:
# a_name='Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)'
# Num Rows: 1981
# b_name='Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)'
# Num Rows: 412

# %%
import numpy as np
from scipy import sparse

def calculate_pmi_matrix(co_counts, alpha=1.0):
    """
    Calculates Alpha-Smoothed PMI for the entire co-occurrence matrix.
    Only computes values for observed entries (non-zeros) to maintain sparsity.
    
    Formula:
    PMI(x,y) = log( (C_xy + alpha) * N_smoothed / (S_x * S_y) )
             = log(C_xy + alpha) + log(N_smoothed) - log(S_x) - log(S_y)
    
    Args:
        co_counts: (n_items, n_items) scipy.sparse matrix (Counts of x, y).
        alpha: Smoothing parameter.
        
    Returns:
        pmi_matrix: (n_items, n_items) scipy.sparse matrix containing PMI values.
    """
    # Ensure we work with a COO matrix to easily access .row, .col, and .data
    # This is a cheap conversion if it's already CSR/CSC
    co_counts_coo = co_counts.tocoo()
    
    n_items = co_counts_coo.shape[0]
    
    # 1. Global Constants
    # Total sum of all counts in the matrix
    N_raw = co_counts_coo.sum()
    
    # Smoothed Normalization Factor: N + alpha * V^2
    N_smoothed = N_raw + (alpha * (n_items ** 2))
    
    # 2. Calculate Smoothed Marginals (S_x and S_y)
    # Row sums gives us C_x (raw marginal counts)
    # We flatten it to a dense 1D array for easy lookup
    C_marginal = np.array(co_counts_coo.sum(axis=1)).flatten()
    
    # Apply smoothing to marginals: C_x + alpha * V
    S_marginal = C_marginal + (alpha * n_items)
    
    # 3. Vectorized PMI Calculation on Non-Zero Elements
    # We operate directly on the 'data' array of the sparse matrix.
    
    # rows and cols indices for every non-zero entry
    rows = co_counts_coo.row
    cols = co_counts_coo.col
    
    # Data is C_xy
    C_xy = co_counts_coo.data
    
    # Look up the marginals for every interaction
    # If interaction is (item 5, item 99), we grab S_marginal[5] and S_marginal[99]
    Sx_vals = S_marginal[rows]
    Sy_vals = S_marginal[cols]
    
    # Apply the Log-PMI formula decomposed:
    # log(C_xy + alpha) + log(N_smoothed) - log(Sx) - log(Sy)
    
    term1 = np.log(C_xy + alpha)
    term2 = np.log(N_smoothed)
    term3 = np.log(Sx_vals)
    term4 = np.log(Sy_vals)
    
    pmi_data = term1 + term2 - term3 - term4
    
    # 4. Reconstruct Sparse Matrix
    # We create a new CSR matrix with the calculated PMI values
    pmi_matrix = sparse.csr_matrix(
        (pmi_data, (rows, cols)), 
        shape=co_counts_coo.shape
    )
    
    return pmi_matrix

# %%
import numpy as np
import scipy.sparse as sp

class SparseEntropyReducer:
    def __init__(self, cooccurrence_matrix, total_users, item_names=None):
        """
        Args:
            cooccurrence_matrix (sp.csr_array): Sparse square matrix of co-occurrences.
                                                Diagonal must be count of users who liked item i.
            total_users (int): Total N.
            item_names (list): For display.
        """
        # Ensure input is a CSR matrix for fast row slicing and arithmetic
        self.cooc = sp.csr_matrix(cooccurrence_matrix, dtype=np.float64)
        self.N = float(total_users)
        self.num_items = self.cooc.shape[0]
        self.item_names = item_names if item_names is not None else [f"Item_{i}" for i in range(self.num_items)]
        
        # Pre-compute marginal probabilities P(x=1)
        # The diagonal contains the raw counts of likes per item
        self.diag_counts = self.cooc.diagonal()
        self.p_i = self.diag_counts / self.N

    def _compute_sparse_correlation(self):
        """
        Computes Pearson Correlation ONLY for non-zero co-occurrences.
        Returns a sparse matrix.
        """
        # 1. Create a copy to work on
        C = self.cooc.copy()
        
        # 2. Get the row and col indices for all non-zero elements
        rows, cols = C.nonzero()
        
        # 3. Calculate Covariance: P(xy) - P(x)P(y)
        # P(xy) = count / N
        p_xy = C.data / self.N
        
        # P(x)P(y) for each non-zero element
        # We use numpy indexing to grab the marginals corresponding to the sparse indices
        p_x_p_y = self.p_i[rows] * self.p_i[cols]
        
        covariance = p_xy - p_x_p_y
        
        # 4. Calculate Standard Deviations
        # Var(x) = p(1-p)
        var = self.p_i * (1 - self.p_i)
        sigma = np.sqrt(var)
        # Avoid div by zero
        sigma[sigma < 1e-9] = 1.0
        
        # Denominator: sigma_x * sigma_y
        denom = sigma[rows] * sigma[cols]
        
        # 5. Update the sparse matrix data directly
        C.data = covariance / denom
        
        # Ensure diagonal is exactly 1.0
        C.setdiag(1.0)
        
        return C

    def _compute_sparse_mi(self):
        """
        Computes Mutual Information ONLY for non-zero co-occurrences.
        (Approximation: assumes MI is 0 if co-occurrence is 0 to save memory)
        """
        M = self.cooc.copy()
        rows, cols = M.nonzero()
        
        # P(x=1), P(y=1)
        pi = self.p_i[rows]
        pj = self.p_i[cols]
        p_xy = M.data / self.N
        
        # We assume sparsity implies we only care about the positive relationships
        # Standard PMI: log( P(xy) / (P(x)P(y)) )
        # Weighted by P(xy)
        
        # Avoid log(0)
        mask = p_xy > 1e-10
        
        # Calculate PMI terms efficiently on vectors
        lift = p_xy[mask] / (pi[mask] * pj[mask])
        
        # MI contribution from the (1,1) state
        # Note: A full MI calc includes (1,0), (0,1), (0,0). 
        # But (0,0) is dense. We stick to (1,1) for sparse 'Positive Information'
        mi_values = np.zeros_like(p_xy)
        mi_values[mask] = p_xy[mask] * np.log2(lift + 1e-15) 
        
        M.data = mi_values
        
        # Set diagonal to Entropy: -p log p - (1-p) log (1-p)
        # This is the "self-information"
        H = -self.p_i * np.log2(self.p_i + 1e-15) - (1-self.p_i) * np.log2(1-self.p_i + 1e-15)
        M.setdiag(H)
        
        return M

    def find_sequence(self, method='mi', k=10, debug=True):
        # 1. Initialize Sparse Matrix
        if method == 'mi':
            if debug: print("Constructing Sparse MI Matrix...")
            Matrix = self._compute_sparse_mi()
            metric_name = "Positive Entropy"
        else:
            if debug: print("Constructing Sparse Correlation Matrix...")
            Matrix = self._compute_sparse_correlation()
            # For Variance reduction, we operate on r^2
            Matrix.data = Matrix.data ** 2
            metric_name = "Variance"

        selected_indices = []
        # Keep track of which items are 'active' (not yet asked)
        # We can't easily delete rows in CSR, so we mask scores.
        is_active = np.ones(self.num_items, dtype=bool)

        if debug: print(f"\n--- Starting Sparse Selection ({method.upper()}) ---")

        for step in range(k):
            # A. Calculate Global Score (Sum of row)
            # CSR matrix sum(axis=1) is fast
            # This returns a dense matrix (N x 1), which is fine for the vector of items
            scores = np.array(Matrix.sum(axis=1)).flatten()
            
            # Mask selected
            scores[~is_active] = -1.0
            
            # B. Pick Best
            best_idx = np.argmax(scores)
            best_score = scores[best_idx]
            
            if best_score <= 0 and step > 0:
                print("No more information gain available.")
                break
                
            selected_indices.append(best_idx)
            is_active[best_idx] = False
            
            name = self.item_names[best_idx]
            if debug:
                print(f"Q{step+1}: {name:<30} (Score: {best_score:.4f})")
            
            # C. Sparse Schur Update
            # Get the column vector v for the selected item
            # Slicing a CSR column returns a CSC matrix, efficient
            v = Matrix[:, [best_idx]] 
            
            # Denominator (Variance/Entropy of the item itself)
            d = Matrix[best_idx, best_idx]
            
            if d < 1e-10: continue
                
            # --- START FIX: PRUNING ---
            # Drake (and other hubs) connect to too many items. 
            # v @ v.T creates a dense N^2 block. We must prune v.

            # 1. Define a max capacity for the update (e.g., top 1000 correlations)
            max_neighbors = 1000 

            # 2. Check if v is too dense
            if v.nnz > max_neighbors:
                # Get indices of the top K absolute values in v
                # We use argpartition for speed (O(n)) rather than full sort
                data_abs = np.abs(v.data)

                # Indices of top max_neighbors elements
                # Note: argpartition puts the k-th largest at the pivot, 
                # everything larger after it.
                idx_top = np.argpartition(data_abs, -max_neighbors)[-max_neighbors:]

                # 3. Create a mask to zero out the "tail" connections
                mask = np.zeros_like(v.data, dtype=bool)
                mask[idx_top] = True

                # Apply mask: Zero out small correlations
                v.data[~mask] = 0

                # 4. actually remove the zeros from the sparse structure
                v.eliminate_zeros()

            # --- END FIX ---

            # Outer product v * v.T
            # v is (M x 1), v.T is (1 x M)
            # The result is M x M. 
            # WARNING: This step induces "fill-in".
            # If item k is correlated with 1000 items, this adds 1000x1000 entries.
            # However, since v is sparse, the update only affects the "neighborhood" of k.
            correction = (v @ v.T) / d
            
            # We convert correction to CSR to match Matrix format for subtraction
            correction = correction.tocsr()
            
            # Subtract
            Matrix = Matrix - correction
            
            # D. Pruning (Crucial for Speed/Memory)
            # Remove near-zero elements to keep the matrix sparse
            Matrix.data[np.abs(Matrix.data) < 1e-6] = 0
            Matrix.eliminate_zeros()
            
            # E. Explicitly zero out the selected row/col to prevent re-selection
            # (Though the mask handles re-selection, this keeps sum accurate)
            # In CSR, zeroing rows is fast-ish, cols is slow. 
            # We skip this and rely on the mask `is_active` for selection logic
            # but for the math to be correct (remaining entropy), we should ideally zero it.
            # But the Schur update naturally reduces the variance of the selected item to 0.
            # So `Matrix[best_idx, best_idx]` becomes ~0 automatically.

        return selected_indices

# %%
solver = SparseEntropyReducer(X, total_users=mat.shape[0], item_names=list(idx2cat.values()))

# Run with Mutual Information (Recommended for Binary Data)
seq_mi = solver.find_sequence(method='mi', k=100)
# seq_mi = solver.find_sequence(method='corr', k=20)
# Out:
# Constructing Sparse MI Matrix...
#
# --- Starting Sparse Selection (MI) ---
# Q1: Drake (spotify:artist:3TVXtAsR1Inumwj472S9r4) (Score: 10.2306)
# Q2: Rihanna (spotify:artist:5pKCCKE2ajJHZ9KAiaK11H) (Score: 7.3244)
# Q3: The Chainsmokers (spotify:artist:69GGBxA162lTqCwzJG5jLp) (Score: 6.7538)
# Q4: Kanye West (spotify:artist:5K4W6rqBFWDnAN6FQUkS6x) (Score: 5.5884)
# Q5: Calvin Harris (spotify:artist:7CajNmpbOovFoOoasH2HaY) (Score: 5.2453)
# Q6: Queen (spotify:artist:1dfeR4HaWDbWqFHLkxsg1d) (Score: 5.1289)
# Q7: Ed Sheeran (spotify:artist:6eUKZXaKkcviH0Ku9w2n3V) (Score: 4.8121)
# Q8: Future (spotify:artist:1RyvyyTE3xzB2ZywiAwp0i) (Score: 4.6893)
# Hozier (spotify:artist:2FXC3k01G6Gw61bmprjgqS)
# Nelly (spotify:artist:2gBjLmx6zQnFGQJCAQpRgw)
# Trey Songz (spotify:artist:2iojnBLj0qIMiKPvVhLnsH)
# John Mayer (spotify:artist:0hEurMDQu99nJRq8pTxO14)
# Kodak Black (spotify:artist:46SHBwWsqBkxI7EeeBEQG7)
# Train (spotify:artist:3FUY2gzHeIiaesXtOAdB7A)
# Sam Hunt (spotify:artist:2kucQ9jQwuD8jWdtR9Ef38)
# Michael Jackson (spotify:artist:3fMbdgg4jU18AjLCKBhRSm)
# Gucci Mane (spotify:artist:13y7CgLHjMVRMDqxdx0Xdo)
# Red Hot Chili Peppers (spotify:artist:0L8ExT028jH3ddEcZwqJJ5)
# OutKast (spotify:artist:1G9G7WwrXka3Z1r7aIDjI7)
# R. Kelly (spotify:artist:2mxe0TnaNL039ysAj51xPQ)
# One Direction (spotify:artist:4AK6F7OLvEQ5QYCBNiQWHq)
# Martin Garrix (spotify:artist:60d24wfXkVzDSfLS6hyCjZ)
# 21 Savage (spotify:artist:1URnnhqYAYcrqrcwql10ft)
# The Killers (spotify:artist:0C0XlULifJtAgn6ZNCW2eu)
# Macklemore & Ryan Lewis (spotify:artist:5BcAKTbp20cv7tC5VqPFoC)
# Meek Mill (spotify:artist:20sxb77xiYeusSH8cVdatc)
# Panic! At The Disco (spotify:artist:20JZFwl6HVl6yg8a4H3ZqK)
# ZAYN (spotify:artist:5ZsFI1h6hIdQRw2ti0hz81)
# T-Pain (spotify:artist:3aQeKQSyrW4qWr35idm0cy)
# Fifth Harmony (spotify:artist:1l8Fu6IkuTP0U5QetQJ5Xt)
# Bryson Tiller (spotify:artist:2EMAnMvWE2eb56ToJVfCWs)

# %%
solver = SparseEntropyReducer(X, total_users=mat.shape[0], item_names=None)

# Run with Mutual Information (Recommended for Binary Data)
# seq_mi = solver.find_sequence(method='mi', k=3)
seq_mi = solver.find_sequence(method='corr', k=2)
# Out:
# Constructing Sparse Correlation Matrix...
#
# --- Starting Sparse Selection (CORR) ---
# Q1: Item_266122                    (Score: 105.8117)
# Q2: Item_201843                    (Score: 104.1774)

# %%
solver = SparseEntropyReducer(X, total_users=mat.shape[0], item_names=list(idx2cat.values()))

# Run with Mutual Information (Recommended for Binary Data)
# seq_mi = solver.find_sequence(method='mi', k=3)
seq_mi = solver.find_sequence(method='corr', k=20)
# Out:
# Constructing Sparse Correlation Matrix...
#
# --- Starting Sparse Selection (CORR) ---
# Q1: Andra Dare (spotify:artist:5pCtXrHmbzNfAuKoB2Cw8W) (Score: 105.8117)
# Q2: W Beale (spotify:artist:3ntFpGevAtluTkORl5UfXL) (Score: 104.1774)
# Q3: Brooklyn Broadcasters (spotify:artist:3p2n2EKhfTN89fQpkbeHdo) (Score: 94.3391)
# Q4: am. (spotify:artist:5nnaEvQwoHrMWr09wgdwaE) (Score: 89.3550)
# Q5: Beatlemania Revival Band (spotify:artist:6Vl8JtRSKEpC2T8ZopA1a3) (Score: 89.1331)
# Q6: Nu Soul Guru (spotify:artist:6gywFExFXz84Q3wrDD0uqk) (Score: 71.4153)
# Q7: Mind Flavour (spotify:artist:63FS7pvrxyFgAgZkMs2qGj) (Score: 69.6600)
# Q8: Mirko Loko (spotify:artist:0pOtG2vmNcA194HMtKRM8W) (Score: 69.5262)
# Q9: Hogs (spotify:artist:2IobM3ozuXPNqeefEakEkm) (Score: 68.8138)
# Q10: Charlene (spotify:artist:6V3LuodmG70Gbx6FvEWPo8) (Score: 66.1793)
# Q11: George Thomson (spotify:artist:1Ca019OH5r2VyHrXmhD6Ns) (Score: 65.8488)
# Q12: Rundkirche Klingenthal (spotify:artist:1KdVbw4XzafaOgbK30nU7i) (Score: 64.5000)
# Q13: Edwin Montoya (spotify:artist:3owb5B5H82e72R5GJYSnwb) (Score: 63.9258)
# Q14: Melvin Pierce (spotify:artist:2I9f1K9LbVEnZ8Y4RMyFqb) (Score: 63.4347)
# Q15: Astrid Nijgh (spotify:artist:53h41ZnbPtgDG5K7HJ56r7) (Score: 63.3653)
# Q16: Jerry Cole (spotify:artist:3FKdxBym7iSS4Lt501u6oA) (Score: 62.4367)
# Q17: Forças do Gueto (spotify:artist:2zCIzHdWhIMpcZToQWoJRx) (Score: 62.3574)
# Q18: A Loathing Requiem (spotify:artist:3nJxgLMUAuJX4ovwESqyct) (Score: 62.2320)
# Q19: Manie Jackson (spotify:artist:3bKlEO17W5YwQRkmli678G) (Score: 61.8828)
# Q20: Linda & The Vistas (spotify:artist:2tu7CtHbzKSDHPN3reWYmn) (Score: 61.8079)

# %%
solver = SparseEntropyReducer(X, total_users=mat.shape[0], item_names=list(idx2cat.values()))

# Run with Mutual Information (Recommended for Binary Data)
seq_mi = solver.find_sequence(method='mi', k=20)
# seq_mi = solver.find_sequence(method='corr', k=20)
# Out:
# Constructing Sparse MI Matrix...
#
# --- Starting Sparse Selection (MI) ---
# Q1: Drake (spotify:artist:3TVXtAsR1Inumwj472S9r4) (Score: 10.2306)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[25], line 4
#       1 solver = SparseEntropyReducer(X, total_users=mat.shape[0], item_names=list(idx2cat.values()))
#       3 # Run with Mutual Information (Recommended for Binary Data)
# ----> 4 seq_mi = solver.find_sequence(method='mi', k=20)
#       5 # seq_mi = solver.find_sequence(method='corr', k=20)
#
# Cell In[20], line 161, in SparseEntropyReducer.find_sequence(self, method, k, debug)
#     153 if d < 1e-10: continue
#     155 # Outer product v * v.T
#     156 # v is (M x 1), v.T is (1 x M)
#     157 # The result is M x M.
#     158 # WARNING: This step induces "fill-in".
#     159 # If item k is correlated with 1000 items, this adds 1000x1000 entries.
#     160 # However, since v is sparse, the update only affects the "neighborhood" of k.
# --> 161 correction = (v @ v.T) / d
#     163 # We convert correction to CSR to match Matrix format for subtraction
#     164 correction = correction.tocsr()
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\_base.py:732, in _spbase.__matmul__(self, other)
#     729 if isscalarlike(other):
#     730     raise ValueError("Scalar operands are not allowed, "
#     731                      "use '*' instead")
# --> 732 return self._matmul_dispatch(other)
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\_base.py:636, in _spbase._matmul_dispatch(self, other)
#     632     if N != other.shape[0]:
#     633         raise ValueError(
#     634             f"{err_prefix} (n,k={N}),(k={other.shape[0]},m)->(n,m)"
#     635         )
# --> 636     return self._matmul_sparse(other)
#     638 # If it's a list or whatever, treat it like an array
#     639 other_a = np.asanyarray(other)
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\_compressed.py:586, in _cs_matrix._matmul_sparse(self, other)
#     584 indptr = np.empty(major_dim + 1, dtype=idx_dtype)
#     585 indices = np.empty(nnz, dtype=idx_dtype)
# --> 586 data = np.empty(nnz, dtype=upcast(self.dtype, other.dtype))
#     588 fn = getattr(_sparsetools, self.format + '_matmat')
#     589 fn(M, N, np.asarray(self.indptr, dtype=idx_dtype),
#     590    np.asarray(self.indices, dtype=idx_dtype),
#     591    self.data,
#    (...)
#     594    other.data,
#     595    indptr, indices, data)
#
# MemoryError: Unable to allocate 60.5 GiB for an array with shape (8117469409,) and data type float64

# %%
# 1. Create Dummy Data
# Let's pretend we have 5 items: 
# Items 0,1 are highly correlated (Action movies)
# Items 2,3 are highly correlated (Romance movies)
# Item 4 is a bridge (Action-Romance)

N_users = 1000

# Co-occurrence counts (symmetric)
# Diagonals are total likes per item
counts = np.array([
    [500, 450,  50,  50, 300], # Item 0: Popular, linked to 1 and 4
    [450, 500,  50,  50, 300], # Item 1: Identical to 0
    [ 50,  50, 400, 380, 200], # Item 2: Romance cluster
    [ 50,  50, 380, 400, 200], # Item 3: Romance cluster
    [300, 300, 200, 200, 600]  # Item 4: The Bridge (Broad appeal)
])

names = ["Action Hit A", "Action Hit B", "Romance Hit A", "Romance Hit B", "The Bridge Movie"]

solver = OptimalQuestionSequencer(counts, N_users, names)

# Run with Mutual Information (Recommended for Binary Data)
# seq_mi = solver.find_sequence(method='mi', k=3)
seq_mi = solver.find_sequence(method='corr', k=3)

# Run with Correlation (Gaussian assumption)
# seq_corr = solver.find_sequence(method='corr', k=3)

# %%
import numpy as np
import pandas as pd

# Assume we have the same 'matrix_small' (Users x Movies) from the previous step
# 1. Compute the Correlation Matrix (Proxy for Covariance in standardized data)
# We use correlation because it's normalized (-1 to 1)
Sigma = matrix_small.corr().values
movie_indices = np.arange(len(Sigma))
active_mask = np.ones(len(Sigma), dtype=bool) # Track which movies are still candidates

selected_indices = []
n_questions = 10

print("--- OPTIMAL SEQUENCE (Schur Complement / Gaussian Process) ---")

for step in range(n_questions):
    # 1. Score candidates
    # The 'Information Gain' of asking about movie k is the sum of variance reduction
    # Variance Reduction for target j given source k = Cov(j,k)^2 / Var(k)
    # Since it's a correlation matrix, Var(k) is 1.0 on the diagonal (mostly).
    # So Score(k) = Sum(Cov(j,k)^2) for all remaining j
    
    # We only look at candidates we haven't asked yet
    candidates = movie_indices[active_mask]
    
    best_idx = -1
    best_score = -1
    
    for k in candidates:
        # Calculate reduction in global variance if we ask k
        # We assume diagonal is 1, so reduction is simply sum of squared correlations
        # (This is the Frobenious norm of the column)
        reduction = np.sum(Sigma[active_mask, k] ** 2)
        
        if reduction > best_score:
            best_score = reduction
            best_idx = k
            
    # 2. Select the best
    selected_indices.append(best_idx)
    title = movie_names.iloc[best_idx]
    print(f"Q{step+1}: {title} (Variance Reduction: {best_score:.2f})")
    
    # 3. The Theoretical Update (Schur Complement)
    # Sigma_new = Sigma - (Cov_k * Cov_k^T) / Var_k
    # This removes all information 'explained' by the selected movie
    
    k = best_idx
    sigma_k = Sigma[:, k] # The column of correlations with the chosen movie
    var_k = Sigma[k, k]   # The variance of the chosen movie (approx 1.0)
    
    if var_k < 1e-9:
        # Edge case: Variance collapsed (shouldn't happen with correlation matrix)
        break
        
    # Outer product to get correction matrix
    correction = np.outer(sigma_k, sigma_k) / var_k
    
    # Update the global matrix
    Sigma = Sigma - correction
    
    # 4. Remove selected from future candidates
    # (We don't remove it from the matrix entirely to keep indices aligned, 
    # but we ignore it in the loop)
    active_mask[best_idx] = False

print("\nNote: The matrix is now mathematically 'conditioned' on the selected movies.")

# %%
import numpy as np
from scipy import sparse

def sparse_laplace_sppmi(X, alpha=1.0, normalize=False):
    # Ensure input is CSR for fast row operations
    if not sparse.isspmatrix_csr(X):
        X = X.tocsr()
        
    # 1. Get Geometry of the Data
    # V: Vocabulary size (rows/cols)
    rows, cols = X.shape
    
    # N_raw: Total real observations
    N_raw = X.sum()
    
    # 2. Calculate "Smoothed" Marginals (The Global Statistics)
    # We pretend we added alpha to every cell, but we compute the sums analytically.
    
    # Virtual Total N = Real N + (alpha * Total Possible Cells)
    N_smoothed = N_raw + (alpha * rows * cols)
    
    # Raw marginals (sum of rows/cols)
    row_sums_raw = np.array(X.sum(axis=1)).flatten()
    col_sums_raw = np.array(X.sum(axis=0)).flatten()
    
    # Smoothed marginals = Raw Sum + (alpha * row_length)
    # Each row has 'cols' number of cells, so we add alpha * cols to the row sum
    P_x = (row_sums_raw + (alpha * cols)) / N_smoothed
    P_y = (col_sums_raw + (alpha * rows)) / N_smoothed
    
    # 3. Operate ONLY on Non-Zero Data (The Sparse Trick)
    # We extract the indices of existing data points to calculate their new PMI
    # efficiently, skipping the billions of zeros.
    
    # Create a copy to store results
    sppmi = X.copy().astype(np.float32)
    
    # Get indices of non-zero elements
    row_indices, col_indices = X.nonzero()
    
    # Get the raw counts
    raw_counts = np.array(X.data)
    
    # Smooth the counts: Count_new = Count_raw + alpha
    smoothed_counts = raw_counts + alpha
    
    # Calculate P(x,y) for these specific entries
    P_xy = smoothed_counts / N_smoothed
    
    # 4. Vectorized PMI Calculation
    # PMI = log( P(x,y) / (P(x) * P(y)) )
    # Note: P_x[row_indices] grabs the specific P(x) for every non-zero entry
    
    # Numerator is P_xy
    # Denominator is P(x) * P(y)
    denominator = P_x[row_indices] * P_y[col_indices]
    
    # Calculate PMI (using log2)
    pmi_values = np.log2(P_xy / denominator)
    
    if normalize:
        pmi_values = pmi_values / -np.log2(P_xy)
    
    # 7. Update the matrix data
    sppmi.data = pmi_values
    
    # 8. Clean up (Remove explicit zeros to keep matrix sparse)
    sppmi.eliminate_zeros()
    
    return sppmi

# %%
alpha = .1 * .85

# %%
sppmi = sparse_laplace_sppmi(X, alpha=alpha)

# %%
# X_coo = X.tocoo()

# row_indices = X_coo.row
# col_indices = X_coo.col

# X2 = csr_array((X_coo.data + alpha, (row_indices, col_indices)), shape=X.shape)

# %%
metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 11.0

# %%
np.argsort(-sppmi[:, a].toarray()).tolist().index(b)
# Out:
# 12

# %%
np.argsort(-sppmi[:, b].toarray()).tolist().index(a)
# Out:
# 10

# %%
top_k = 20

# %%
similarity_scores = sppmi[:, a].toarray()
top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)',
#  'Dustin Tebbutt (spotify:artist:0z9hynUsIjf0ddI4uHqPWX)',
#  'Allman Brown (spotify:artist:239Y6QdFqVFfdsw6moqSEN)',
#  'Ed Tullett (spotify:artist:5VGsR5wapeJIuRPX26IeGn)',
#  'Novo Amor (spotify:artist:0rZp7G3gIH6WkyeXbrZnGi)',
#  'Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO)',
#  'S. Carey (spotify:artist:2LSJrlndCuTpdEluvYHc2E)',
#  'Liza Anne (spotify:artist:426VSUSxx9puUYFgp7l7EQ)',
#  'PHOX (spotify:artist:3ix4iw2URncSdE7X292bXy)',
#  'The Acid (spotify:artist:0bRtSoJSpQdnbB3dWrWprR)',
#  'Lo-Fang (spotify:artist:5EDkJDlRNcMs3ewliB24QA)',
#  'The Careful Ones (spotify:artist:1DdAoWvETBUklcJCOISZx1)',
#  'Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)',
#  'Snakadaktal (spotify:artist:0SdEkx5Ai2gl0W7pnhlsfy)',
#  'Matthew And The Atlas (spotify:artist:0lSENl3bteP8p2NbiSP7RM)',
#  'Nick Mulvey (spotify:artist:3x8FbPjh2Qz55XMdE2Yalj)',
#  'SOHN (spotify:artist:6XZYAWJLL8UIbxAqjKj3cg)',
#  'Vök (spotify:artist:7oDTyDfeA2JE2jUZztkBj8)',
#  'Axel Flovent (spotify:artist:6jn7W8NuX94FWZyeGlyCaJ)',
#  'Vancouver Sleep Clinic (spotify:artist:77BznF1Dr1k5KyEZ6Nn3jB)']

# %%
similarity_scores = sppmi[:, b].toarray()
top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)',
#  'Gabrielle (spotify:artist:4OovmAu23KrDlDQI2UbneL)',
#  'Elsa & Emilie (spotify:artist:4HDNQLqhooVfWXtIRMyqMY)',
#  'Nils Bech (spotify:artist:57QhXfAsLsIRtgC1VfHu1F)',
#  'Rockettothesky (spotify:artist:0nu7qEOc8X8UFK10d8lsLw)',
#  'Susanne Sundfør (spotify:artist:54KCNI7URCrG6yjQK3Ukow)',
#  'Ings (spotify:artist:3wJ2NeHF58Im2tojNX8ESR)',
#  'Kjartan Lauritzen (spotify:artist:0TW5M8RYADmgeCP1q523hf)',
#  'Alice Boman (spotify:artist:3WiytRnvoL0kT3oAGl9TCt)',
#  'Karpe Diem (spotify:artist:3X23gpg1vPacr0hBARyxtN)',
#  'Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)',
#  'Hanzee (spotify:artist:5yM1po4NHvE2yE1Kf84LWJ)',
#  'ZL-Project (spotify:artist:4w8PGLhS3yzYSzeV3x2hkA)',
#  'Majical Cloudz (spotify:artist:4BEYBN6NCPrFk3sOLMTby3)',
#  'The White Birch (spotify:artist:3pDnwHQUEXbkNX3cvidKpG)',
#  'Amason (spotify:artist:4cJKxS7uOPhwb5UQ70sYpN)',
#  'SOAK (spotify:artist:4PLsMEk2DCRVlVL2a9aZAv)',
#  'Hkeem (spotify:artist:46XcyK8FnyCJJlvYCUwVZH)',
#  'Oh Pep! (spotify:artist:3L9rqEIsNSaOcx2QIstn7v)',
#  'Farao (spotify:artist:6XIX2G6ZGiVQgMr6SSTMFu)']

# %%
lambda_ = optimize_lambda_using_a_to_b_matching(artist_mat, a, b, fast_approximation=True)
# Out:
# lambda_: 1000000
# error: 339.0
# lambda_: 100000.0
# error: 157.0
# lambda_: 10000.0
# error: 38.0
# lambda_: 1000.0
# error: 5.0
# lambda_: 100.0
# error: 3.0
# lambda_: 10.0
# error: 3.5

# %%
# check final error for EASE
a_to_b_error_metric(artist_mat, a, b, lambda_)
# Out:
# lambda_: 100
# error: 3.0
# 3.0

# %%
# using EASE

similarity_scores = calculate_ease_for_item_cg(artist_mat, a, lambda_)
top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Allman Brown (spotify:artist:239Y6QdFqVFfdsw6moqSEN)',
#  'PHOX (spotify:artist:3ix4iw2URncSdE7X292bXy)',
#  'The Acid (spotify:artist:0bRtSoJSpQdnbB3dWrWprR)',
#  'Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)',
#  'Dustin Tebbutt (spotify:artist:0z9hynUsIjf0ddI4uHqPWX)',
#  'The Careful Ones (spotify:artist:1DdAoWvETBUklcJCOISZx1)',
#  'Liza Anne (spotify:artist:426VSUSxx9puUYFgp7l7EQ)',
#  'Snakadaktal (spotify:artist:0SdEkx5Ai2gl0W7pnhlsfy)',
#  'Vök (spotify:artist:7oDTyDfeA2JE2jUZztkBj8)',
#  'Seoul (spotify:artist:3e69LorE0YSsEaYY6x9XuG)',
#  'Only Real (spotify:artist:5cyHu7tidauRJ9UawaPwG5)',
#  'Big Scary (spotify:artist:4mLYW48jy9Pwv6KpT74Evf)',
#  'SOHN (spotify:artist:6XZYAWJLL8UIbxAqjKj3cg)',
#  'San Fermin (spotify:artist:7fSnislKgW9Mz0YIqWQmGt)',
#  'Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO)',
#  'Caroline Smith (spotify:artist:47blM5Op3BJODxUJImwdYE)',
#  'Neulore (spotify:artist:6SLbaDa56f1CZlUNuF0gk3)',
#  'Lo-Fang (spotify:artist:5EDkJDlRNcMs3ewliB24QA)',
#  'Ásgeir Trausti (spotify:artist:7fNWySjsDn74LCawyJ27EQ)',
#  'Samaris (spotify:artist:1Xl5hsislt88ijOD3EZsOY)']

# %%
# using EASE

similarity_scores = calculate_ease_for_item_cg(artist_mat, b, lambda_)
top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Susanne Sundfør (spotify:artist:54KCNI7URCrG6yjQK3Ukow)',
#  'Gabrielle (spotify:artist:4OovmAu23KrDlDQI2UbneL)',
#  'Elsa & Emilie (spotify:artist:4HDNQLqhooVfWXtIRMyqMY)',
#  'Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)',
#  'Alice Boman (spotify:artist:3WiytRnvoL0kT3oAGl9TCt)',
#  'Majical Cloudz (spotify:artist:4BEYBN6NCPrFk3sOLMTby3)',
#  'Rockettothesky (spotify:artist:0nu7qEOc8X8UFK10d8lsLw)',
#  'Nils Bech (spotify:artist:57QhXfAsLsIRtgC1VfHu1F)',
#  'Rubblebucket (spotify:artist:6xriZDSK3wPXhOoZXr9fzF)',
#  'Ings (spotify:artist:3wJ2NeHF58Im2tojNX8ESR)',
#  'Max Jury (spotify:artist:3MuPVbFDynbq9zRTAqjRxi)',
#  'SOAK (spotify:artist:4PLsMEk2DCRVlVL2a9aZAv)',
#  'Amason (spotify:artist:4cJKxS7uOPhwb5UQ70sYpN)',
#  'Joseph (spotify:artist:5Wfvw7rDz7HA6gE2z6QhqO)',
#  'MUNA (spotify:artist:6xdRb2GypJ7DqnWAI2mHGn)',
#  'Kjartan Lauritzen (spotify:artist:0TW5M8RYADmgeCP1q523hf)',
#  'The Dø (spotify:artist:2mcNCn1qbZUQ3J9KHapUxj)',
#  'Karpe Diem (spotify:artist:3X23gpg1vPacr0hBARyxtN)',
#  'Matrimony (spotify:artist:4V5UtbLYaFishr7psURF3Q)',
#  'Phoria (spotify:artist:0HDxlFsXwyrpufs4YgTNMm)']

# %%
import numpy as np
from scipy import sparse

def sparse_laplace_sppmi_alt(X, i, p_x, N, alpha, normalize=False):
    x = X[i, :].toarray() + alpha
    
#     N = X.sum() + X.shape[0] * alpha + X.shape[1] * alpha
#     N = N + X.shape[0] * alpha + X.shape[1] * alpha
    
#     p_x = X.sum(axis=0) + X.shape[0] * alpha
    p_x = p_x + X.shape[0] * alpha
    
    N = p_x.sum()
    
    p_x = p_x / N
    p_xy = x / N
    
    assert np.isclose(p_x.sum(), 1)
    assert np.isclose(p_xy.sum(), p_x[i])
    
    pmi = p_xy / (p_x[i] * p_x)
    
    if normalize:
        return pmi / -np.log2(p_xy)
    else:
        return pmi

# %%
p_x = X.sum(axis=0)
N = p_x.sum()

# %%
alpha = .1 * .85
normalize = False

metric = (np.argsort(-sparse_laplace_sppmi_alt(X, a, p_x, N, alpha, normalize)).tolist().index(b) + 
          np.argsort(-sparse_laplace_sppmi_alt(X, b, p_x, N, alpha, normalize)).tolist().index(a))/2
metric
# Out:
# 11.0

# %%
# %%time

alpha = .1 * .8
normalize = True

metric = (np.argsort(-sparse_laplace_sppmi_alt(X, a, p_x, N, alpha, normalize)).tolist().index(b) + 
          np.argsort(-sparse_laplace_sppmi_alt(X, b, p_x, N, alpha, normalize)).tolist().index(a))/2
metric
# Out:
# CPU times: total: 812 ms
# Wall time: 851 ms
# 11.5

# %%
# %%time

alpha = .1 * .8

sppmi = sparse_laplace_sppmi(X, alpha=alpha, normalize=True)

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# CPU times: total: 25.2 s
# Wall time: 26 s
# 19.5

# %%
np.argsort(-scores).tolist().index(a)
# Out:
# 12

# %%
metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric

# %%
def add_sparse_constant(X, alpha):
    X_coo = X.tocoo()

    row_indices = X_coo.row
    col_indices = X_coo.col

    X2 = csr_array((X_coo.data + alpha, (row_indices, col_indices)), shape=X.shape)
    
    return X2

# %%
from ipdb import set_trace

# %%
import numpy as np
from scipy import sparse

def sparse_laplace_sppmi_alt(X, alpha=1.0, normalize=False):
    X = add_sparse_constant(X, alpha)
    
    N = X.sum()
    
    P_x = X.sum(axis=0) / N
#     P_y = X.sum(axis=1) / N
    
#     assert np.allclose(P_x, P_y)
    
    P_y = P_x
    
    # Create a copy to store results
    sppmi = X.copy().astype(np.float32)
        
    P_xy = np.array(X.data) / N
    
    set_trace()
    
    # Get indices of non-zero elements
    row_indices, col_indices = X.nonzero()
    
    denominator = P_x[row_indices] * P_y[col_indices]
    
    # Calculate PMI (using log2)
    pmi_values = np.log2(P_xy / denominator)
    
    if normalize:
        pmi_values = pmi_values / -np.log2(P_xy)
    
    # 7. Update the matrix data
    sppmi.data = pmi_values
    
    # 8. Clean up (Remove explicit zeros to keep matrix sparse)
    sppmi.eliminate_zeros()
    
    return sppmi

# %%
alpha
# Out:
# 0.085

# %%
# v1 = X.sum()

# v2 = add_sparse_constant(X, 1).sum()

# X.nnz

# v2 - v1

# %%
sppmi = sparse_laplace_sppmi_alt(X, alpha)
# Out:
# > c:\users\johns\appdata\local\temp\ipykernel_10088\3408885922.py(24)sparse_laplace_sppmi_alt()
#
# ipdb> X
# <Compressed Sparse Row sparse array of dtype 'float64'
# 	with 244376304 stored elements and shape (295860, 295860)>
# ipdb> X.eliminate_zeros()
# ipdb> X
# <Compressed Sparse Row sparse array of dtype 'float64'
# 	with 244376304 stored elements and shape (295860, 295860)>
# ipdb> P_xy
# array([9.37481183e-06, 2.53631616e-06, 4.61541310e-06, ...,
#        4.54252958e-10, 4.54252958e-10, 4.54252958e-10], shape=(244376304,))
# ipdb> P_x
# array([6.33405618e-04, 1.08530877e-03, 2.36986468e-03, ...,
#        1.36275887e-09, 1.36275887e-09, 1.90786242e-08], shape=(295860,))
# ipdb> row_indices
# *** NameError: name 'row_indices' is not defined
# ipdb> n
# > c:\users\johns\appdata\local\temp\ipykernel_10088\3408885922.py(26)sparse_laplace_sppmi_alt()
#
# ipdb> exit

# %%
metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 2170.0

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1/2, normalize=True)

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 14.0

# %%
similarity_scores = sppmi[:, a].toarray()
top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)',
#  'Dustin Tebbutt (spotify:artist:0z9hynUsIjf0ddI4uHqPWX)',
#  'Novo Amor (spotify:artist:0rZp7G3gIH6WkyeXbrZnGi)',
#  'Allman Brown (spotify:artist:239Y6QdFqVFfdsw6moqSEN)',
#  'Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO)',
#  'Lo-Fang (spotify:artist:5EDkJDlRNcMs3ewliB24QA)',
#  'Ed Tullett (spotify:artist:5VGsR5wapeJIuRPX26IeGn)',
#  'S. Carey (spotify:artist:2LSJrlndCuTpdEluvYHc2E)',
#  'SOHN (spotify:artist:6XZYAWJLL8UIbxAqjKj3cg)',
#  'Liza Anne (spotify:artist:426VSUSxx9puUYFgp7l7EQ)',
#  'PHOX (spotify:artist:3ix4iw2URncSdE7X292bXy)',
#  "Bear's Den (spotify:artist:0nJaMZM8paoA5HEUTUXPqi)",
#  'Matt Corby (spotify:artist:7CIW23FQUXPc1zebnO1TDG)',
#  'The Acid (spotify:artist:0bRtSoJSpQdnbB3dWrWprR)',
#  'The Careful Ones (spotify:artist:1DdAoWvETBUklcJCOISZx1)',
#  'Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)',
#  'Nick Mulvey (spotify:artist:3x8FbPjh2Qz55XMdE2Yalj)',
#  'London Grammar (spotify:artist:3Bd1cgCjtCI32PYvDC3ynO)',
#  'Ásgeir Trausti (spotify:artist:7fNWySjsDn74LCawyJ27EQ)',
#  'Snakadaktal (spotify:artist:0SdEkx5Ai2gl0W7pnhlsfy)']

# %%
similarity_scores = sppmi[:, b].toarray()
top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)',
#  'Gabrielle (spotify:artist:4OovmAu23KrDlDQI2UbneL)',
#  'Elsa & Emilie (spotify:artist:4HDNQLqhooVfWXtIRMyqMY)',
#  'Nils Bech (spotify:artist:57QhXfAsLsIRtgC1VfHu1F)',
#  'Rockettothesky (spotify:artist:0nu7qEOc8X8UFK10d8lsLw)',
#  'Ings (spotify:artist:3wJ2NeHF58Im2tojNX8ESR)',
#  'Susanne Sundfør (spotify:artist:54KCNI7URCrG6yjQK3Ukow)',
#  'Kjartan Lauritzen (spotify:artist:0TW5M8RYADmgeCP1q523hf)',
#  'Karpe Diem (spotify:artist:3X23gpg1vPacr0hBARyxtN)',
#  'Hanzee (spotify:artist:5yM1po4NHvE2yE1Kf84LWJ)',
#  'ZL-Project (spotify:artist:4w8PGLhS3yzYSzeV3x2hkA)',
#  'Alice Boman (spotify:artist:3WiytRnvoL0kT3oAGl9TCt)',
#  'The White Birch (spotify:artist:3pDnwHQUEXbkNX3cvidKpG)',
#  'Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)',
#  'Hkeem (spotify:artist:46XcyK8FnyCJJlvYCUwVZH)',
#  'Farao (spotify:artist:6XIX2G6ZGiVQgMr6SSTMFu)',
#  'Majical Cloudz (spotify:artist:4BEYBN6NCPrFk3sOLMTby3)',
#  'Oh Pep! (spotify:artist:3L9rqEIsNSaOcx2QIstn7v)',
#  'Amason (spotify:artist:4cJKxS7uOPhwb5UQ70sYpN)',
#  'SOAK (spotify:artist:4PLsMEk2DCRVlVL2a9aZAv)']

# %%
def pmi(mat, alpha, i):
    mat2 = add_sparse_constant(mat, alpha)

    py = mat2.sum(axis=0) / (mat2.shape[0] * (alpha + 1))
    pxy = ((mat2[:, i:i+1] * mat2).sum(axis=0)) / (mat2.shape[0] * (alpha + 1))
    px = py[i]

    pmi = pxy / (px * py)
    # pmi = np.log2(pxy) - (np.log2(px) + np.log2(py))
    
    return pmi

# %%
# alpha = 1

# mat.shape[0] + mat.shape[0] * alpha

# (mat[:, 0].toarray() + 1) / (mat.shape[0] + mat.shape[0] * alpha)

# %%
alpha = 2

metric = (np.argsort(-pmi(mat, alpha, a)).tolist().index(b) + np.argsort(-pmi(mat, alpha, b)).tolist().index(a))/2
metric
# Out:
# 2132.0

# %%
alpha = 1

mat2 = add_sparse_constant(mat, alpha)
mat2.sum(axis=0) / (mat2.shape[0] * (alpha + 1))
# Out:
# array([2.2392e-02, 4.0774e-02, 9.7468e-02, ..., 1.0000e-06, 1.0000e-06,
#        1.0000e-06], shape=(295860,))

# %%
mat2.sum(axis=0)
# Out:
# array([ 44784,  81548, 194936, ...,      2,      2,      2],
#       shape=(295860,))

# %%
pmi(mat, 2, a)
# Out:
# array([0.20289211, 0.18570494, 0.5230881 , ..., 0.        , 0.        ,
#        0.        ], shape=(295860,))

# %%
# npmi = (np.log2(pxy + o) - (np.log2(px + np.sqrt(o)) + np.log2(py + np.sqrt(o)))) / -np.log2(pxy + o)

# %%
# py = mat.mean(axis=0)
py = mat.sum(axis=0) / N_smoothd
pxy = (mat[:, i:i+1] * mat).mean(axis=0) + eps
px = py[i]

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1*4)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.2)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 27.0

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1 * 1.1)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 14.0

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1 * .95)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 11.5

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1 * .9)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 11.0

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1 * .85)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 11.0

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1 * .8)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 11.5

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1 * .7)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 11.5

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1 * .7)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1/2)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 18.0

# %%
sppmi = sparse_laplace_sppmi(X, alpha=.1/4)

# sppmi = X

metric = (np.argsort(-sppmi[:, a].toarray()).tolist().index(b) + np.argsort(-sppmi[:, b].toarray()).tolist().index(a))/2
metric
# Out:
# 70.0

# %%
import numpy as np
from scipy import sparse

def get_sppmi_row(X, row_idx, alpha=1.0):
    """
    Calculates a single row of the Laplace Smoothed PPMI matrix efficiently.
    Returns a dense numpy array for the target row index.
    """
    # Ensure X is indexable. 
    # (Even if X is coo_array, we can often slice it in new SciPy, 
    # but converting the source to CSR is generally faster for row access).
    if not sparse.isspmatrix_csr(X):
        X = X.tocsr()
        
    rows, cols = X.shape
    
    # 1. Global Statistics
    N_raw = X.sum()
    N_smoothed = N_raw + (alpha * rows * cols)
    
    # 2. Marginals
    # Sum of all columns (flattened to 1D array)
    col_sums = np.array(X.sum(axis=0)).flatten()
    
    # Get the specific row and FORCE it to be CSR so .indices works
    target_row_sparse = X[row_idx].tocsr()
    row_sum = target_row_sparse.sum()
    
    # Calculate Smoothed Probabilities
    # P(y) is a vector (shape: cols,)
    P_y = (col_sums + (alpha * rows)) / N_smoothed
    
    # P(x) is a scalar (for this specific row)
    P_x = (row_sum + (alpha * cols)) / N_smoothed
    
    # 3. Base Calculation: The "Background" (Zero Count) Case
    # Calculate PMI assuming count=0 (only alpha) for the whole row
    P_xy_base = alpha / N_smoothed
    denominator = P_x * P_y
    
    # Initialize result vector with the base values
    row_ratios = P_xy_base / denominator

    # 4. Update the "Foreground": The Non-Zero Data
    # Now .indices will definitely work because we enforced .tocsr() above
    nz_col_indices = target_row_sparse.indices
    nz_raw_counts = target_row_sparse.data
    
    # Calculate P(x,y) using real counts
    P_xy_real = (nz_raw_counts + alpha) / N_smoothed
    
    # Update only the specific indices
    row_ratios[nz_col_indices] = P_xy_real / denominator[nz_col_indices]
    
    # 5. Compute Log
    pmi_row = np.log2(row_ratios)
    
    return pmi_row

# %%
row = get_sppmi_row(X, a, .1)

# %%
assert (sppmi[0, :].toarray() == sppmi[:, 0].toarray()).all()

# %%
row
# Out:
# array([-1.34328819, -1.37872428,  0.24586819, ..., -2.14993536,
#        -2.14993536, -2.15183566], shape=(295860,))

# %%
np.allclose(sppmi[0, :].toarray(), row)
# Out:
# False

# %%
sppmi[0, :].toarray()
# Out:
# array([6.71543835, 4.06333962, 3.80849313, ..., 0.        , 0.        ,
#        0.        ], shape=(295860,))

# %%
row
# Out:
# array([-1.34328813, -1.37872425,  0.24586817, ...,  0.        ,
#         0.        ,  0.        ], shape=(295860,))

# %%
row
# Out:
# array([-1.34328813, -1.37872425,  0.24586817, ...,  0.        ,
#         0.        ,  0.        ], shape=(295860,))

# %%
np.ar

# %%
X = mat @ mat.T

# %%
X.shape

# %%
target_indices, pmi_values = calculate_sparse_pmi_for_item(mat, i, alpha=1.0)

# %%
import numpy as np
from scipy import sparse

def sparse_laplace_sppmi(X, alpha=1.0):
    # Ensure input is CSR for fast row operations
    if not sparse.isspmatrix_csr(X):
        X = X.tocsr()
        
    # 1. Get Geometry of the Data
    # V: Vocabulary size (rows/cols)
    rows, cols = X.shape
    
    # N_raw: Total real observations
    N_raw = X.sum()
    
    # 2. Calculate "Smoothed" Marginals (The Global Statistics)
    # We pretend we added alpha to every cell, but we compute the sums analytically.
    
    # Virtual Total N = Real N + (alpha * Total Possible Cells)
    N_smoothed = N_raw + (alpha * rows * cols)
    
    # Raw marginals (sum of rows/cols)
    row_sums_raw = np.array(X.sum(axis=1)).flatten()
    col_sums_raw = np.array(X.sum(axis=0)).flatten()
    
    # Smoothed marginals = Raw Sum + (alpha * row_length)
    # Each row has 'cols' number of cells, so we add alpha * cols to the row sum
    P_x = (row_sums_raw + (alpha * cols)) / N_smoothed
    P_y = (col_sums_raw + (alpha * rows)) / N_smoothed
    
    # 3. Operate ONLY on Non-Zero Data (The Sparse Trick)
    # We extract the indices of existing data points to calculate their new PMI
    # efficiently, skipping the billions of zeros.
    
    # Create a copy to store results
    sppmi = X.copy().astype(np.float32)
    
    # Get indices of non-zero elements
    row_indices, col_indices = X.nonzero()
    
    # Get the raw counts
    raw_counts = np.array(X.data)
    
    # Smooth the counts: Count_new = Count_raw + alpha
    smoothed_counts = raw_counts + alpha
    
    # Calculate P(x,y) for these specific entries
    P_xy = smoothed_counts / N_smoothed
    
    # 4. Vectorized PMI Calculation
    # PMI = log( P(x,y) / (P(x) * P(y)) )
    # Note: P_x[row_indices] grabs the specific P(x) for every non-zero entry
    
    # Numerator is P_xy
    # Denominator is P(x) * P(y)
    denominator = P_x[row_indices] * P_y[col_indices]
    
    # Calculate PMI (using log2)
    pmi_values = np.log2(P_xy / denominator)
    
    # 7. Update the matrix data
    sppmi.data = pmi_values
    
    # 8. Clean up (Remove explicit zeros to keep matrix sparse)
    sppmi.eliminate_zeros()
    
    return sppmi

# %%
i = a
j = b

# %%
# eps = 1e-14
eps = 0

# %%
mat.shape
# Out:
# (1000000, 295860)

# %%
alpha = 1

mat = artist_mat
mat = csr_array(mat)

rows = mat.shape[-1]
cols = rows

N_raw = mat.shape[0]
rows, cols = mat.shape

N_smoothed = N_raw + (alpha * rows * cols)

# py = mat.mean(axis=0)
py = mat.sum(axis=0) / N_smoothd
pxy = (mat[:, i:i+1] * mat).mean(axis=0) + eps
px = py[i]

# %%
mat.sum(axis=0) / mat.shape[0]
# Out:
# array([2.2392e-02, 4.0774e-02, 9.7468e-02, ..., 1.0000e-06, 1.0000e-06,
#        1.0000e-06], shape=(295860,))

# %%
mat.mean(axis=0)
# Out:
# array([2.2392e-02, 4.0774e-02, 9.7468e-02, ..., 1.0000e-06, 1.0000e-06,
#        1.0000e-06], shape=(295860,))

# %%
pxy.shape
# Out:
# (295860,)

# %%
px.shape
# Out:
# ()

# %%
pxy.shape
# Out:
# (295860,)

# %%
def metric(i, j, o, call_again = True, eps = 1e-14):
    mat = artist_mat
    mat = csr_array(mat)

    py = mat.mean(axis=0)
    pxy = (mat[:, i:i+1] * mat).mean(axis=0) + eps
    px = py[i]

# %%
import numpy as np

def calculate_smoothed_pmi_item(mat, i, alpha=1.0):
    """
    Calculates PMI for item i against all other items using additive (alpha) smoothing.
    
    Definitions:
    - N: Total number of co-occurrence pairs observed across all users.
    - C(x, y): Number of times x and y co-occur (summing over users).
    - C(y): Total number of co-occurrences involving y.
    
    Args:
        mat: (n_users, n_items) numpy array (binary or counts)
        i: Index of the target item
        alpha: Smoothing parameter (Laplace smoothing)
    """
    n_users, n_items = mat.shape
    
    # 1. Pre-calculate Basket Sizes (Row Sums)
    # This is needed to weight the marginals correctly.
    # If a user bought 3 items, they contribute 3 pairs for each item they bought.
    # shape: (n_users,)
    user_basket_sizes = mat.sum(axis=1)
    
    # 2. Calculate Total Number of Co-occurrences (N)
    # The sum of the entire co-occurrence matrix (without materializing it).
    # It is equal to the sum of squared basket sizes.
    # N_raw = sum( (sum(row))^2 )
    N_raw = np.sum(user_basket_sizes ** 2)
    
    # 3. Calculate Smoothed Normalization Constant
    # Since we add alpha to every cell in the (n_items x n_items) co-occurrence matrix:
    N_smoothed = N_raw + (alpha * (n_items ** 2))
    
    # 4. Calculate Raw Co-occurrence Counts for Item i (Vector C_xy)
    # shape: (n_items,)
    # We multiply column i by the matrix to get interactions, then sum over users.
    C_xy = (mat[:, i:i+1] * mat).sum(axis=0)
    
    # 5. Calculate Raw Marginal Counts (Vector C_y)
    # The marginal count of an item y in co-occurrence space is sum(matrix * basket_sizes).
    # Conceptually: mat.T @ user_basket_sizes
    # This weights popular items by the activity of the users who bought them.
    # shape: (n_items,)
    C_y = np.dot(mat.T, user_basket_sizes)
    
    # 6. Calculate Raw Marginal Count for Target Item i (Scalar C_x)
    C_x = C_y[i]
    
    # 7. Apply Smoothing to Probabilities
    # P(x, y) = (Count(x, y) + alpha) / N_smoothed
    pxy = (C_xy + alpha) / N_smoothed
    
    # P(y) = (Count(y) + alpha * n_items) / N_smoothed
    # Note: We add alpha * n_items because the marginal is the sum of a row of smoothed joints.
    py = (C_y + (alpha * n_items)) / N_smoothed
    
    # P(x) = (Count(x) + alpha * n_items) / N_smoothed
    px = (C_x + (alpha * n_items)) / N_smoothed
    
    # 8. Calculate PMI
    # PMI = log( P(x,y) / (P(x) * P(y)) )
    pmi_vector = np.log(pxy / (px * py))
    
    return pmi_vector

# %%
calculate_smoothed_pmi_item(mat, i)

# %%
o = 3.2e-8

metric(a, b, o)
# Out:
# 17.5

# %%
def metric(i, j, o, lambda_=0, call_again = True, eps = 1e-14):
    mat = artist_mat
    mat = csr_array(mat)

    py = mat.mean(axis=0)
    pxy = (mat[:, i:i+1] * mat).mean(axis=0) + eps
    px = py[i]
    
    pxy_scaled = pxy**lambda_
        
    score = (np.log2(pxy + o) - (np.log2(px + np.sqrt(o)) + np.log2(py + np.sqrt(o)))) / -np.log2(pxy + o)
#     score = (np.log2(pxy + o**2)) - (np.log2(px + o) + np.log2(py + o)) / -np.log2(pxy + o**2)

    score *= pxy_scaled

    if call_again:
        return (metric(j, i, o, lambda_, call_again = False, eps=eps) + np.argsort(-score).tolist().index(j))/2
    else:
        return np.argsort(-score).tolist().index(j)

# %%
metric(a, b, 1e-9, lambda_=0.13408607326731756)
# Out:
# 41.5

# %%
lambda_ = optimize_lambda_using_a_to_b_matching_npmi(artist_mat, a, b)
# Out:
# lambda_: 0.0
# error: 1806.0
# lambda_: 1.0
# error: 426
# lambda_: 2.6180339999999998
# error: 625
# lambda_: 1.6180339748439998
# error: 518
# lambda_: 0.618034
# error: 305.618034
# lambda_: 0.381966025156
# error: 198.381966025156
# lambda_: 0.23606799039126328
# error: 133.23606799039126
# lambda_: 0.145898044373474
# error: 101.14589804437347
# lambda_: 0.09016995195631564
# error: 355.09016995195634
# lambda_: 0.1803398979741049
# error: 107.18033989797411
# lambda_: 0.136098829051948
# error: 99.13609882905195
# lambda_: 0.11855555958323769
# error: 189.11855555958323
# lambda_: 0.1293978965860626
# error: 189.12939789658606
# lambda_: 0.13984179613145
# error: 101.13984179613145
# lambda_: 0.13353930068168363
# error: 193.1335393006817
# lambda_: 0.13752851521543707
# error: 99.13752851521544
# lambda_: 0.13681150750011398
# error: 99.13681150750011
# lambda_: 0.1351211762384716
# error: 96.13512117623847
# lambda_: 0.13451695355954754
# error: 95.13451695355955
# lambda_: 0.13389245935456162
# error: 193.13389245935457
# lambda_: 0.1342784180060459
# error: 95.13427841800605
# lambda_: 0.13439743117597827
# error: 95.13439743117598
# lambda_: 0.13413099492377306
# error: 95.13413099492378
# lambda_: 0.13403988244654363
# error: 193.13403988244653
# lambda_: 0.1341873055288165
# error: 95.13418730552881
# lambda_: 0.13409619305529566
# error: 95.1340961930553
# lambda_: 0.1340746843173131
# error: 193.1340746843173
# lambda_: 0.1341094861857905
# error: 95.13410948618579
# lambda_: 0.13408797744868342
# error: 95.13408797744869
# lambda_: 0.13408289992446643
# error: 193.13408289992446
# lambda_: 0.13409111553107866
# error: 95.13409111553108
# lambda_: 0.13408603800706836
# error: 193.13408603800707
# lambda_: 0.1340891760894636
# error: 95.13408917608946
# lambda_: 0.1340872366479275
# error: 95.13408723664793
# lambda_: 0.1340867788078731
# error: 95.13408677880787
# lambda_: 0.1340864958471529
# error: 95.13408649584716
# lambda_: 0.13408632096780718
# error: 95.13408632096781
# lambda_: 0.1340862128864256
# error: 95.13408621288643
# lambda_: 0.13408614608845704
# error: 95.13408614608846
# lambda_: 0.13408610480504132
# error: 95.13408610480504
# lambda_: 0.13408607929048677
# error: 95.13408607929048
# lambda_: 0.13408606352162458
# error: 193.13408606352164
# lambda_: 0.1340860890361791
# error: 95.13408608903617
# lambda_: 0.13408607326731756
# error: 95.13408607326731
# lambda_: 0.13408606954479418
# error: 193.1340860695448
# lambda_: 0.1340860755679634
# error: 95.13408607556796

# %%
lambda_
# Out:
# np.float64(0.13408607326731756)

# %%
pxy_scaled = pxy**lambda_
        
    return (npmi * pxy_scaled) / pxy_scaled.max()

# %%
# def print_and_return(x, y=1):
#     print(x/y)
#     return x

# res = minimize_scalar(lambda o: print_and_return(2*metric(a, b, abs(o) * 1e-8) + abs(o)*1e-8, 2))
# res

# %%
lambda_ = optimize_lambda_using_a_to_b_matching(artist_mat, a, b, fast_approximation=False)
# Out:
# lambda_: 1000000
# error: 339.0
# lambda_: 100000.0
# error: 157.0
# lambda_: 10000.0
# error: 38.0
# lambda_: 1000.0
# error: 5.0
# lambda_: 100.0
# error: 3.0
# lambda_: 10.0
# error: 3.5
# lambda_: 10.0
# error: 3.5
# lambda_: 100.0
# error: 3.0
# lambda_: 1000.0
# error: 5.0
# lambda_: 443.7694
# error: 3.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 lambda_ = optimize_lambda_using_a_to_b_matching(artist_mat, a, b, fast_approximation=False)
#
# File ~\Projects\find_similar_music_recommendations\ease_recommender.py:194, in optimize_lambda_using_a_to_b_matching(mat, a, b, fast_approximation)
#     192     return round(lambda_*10)
#     193 else:
# --> 194     res = minimize_scalar(lambda lambda_: a_to_b_error_metric(mat, a, b, lambda_),
#     195                           bracket=(lambda_, lambda_*10, lambda_*100))
#     197     return round(res.x)
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\optimize\_minimize.py:975, in minimize_scalar(fun, bracket, bounds, args, method, tol, options)
#     973     res = method(fun, args=args, bracket=bracket, bounds=bounds, **options)
#     974 elif meth == 'brent':
# --> 975     res = _recover_from_bracket_error(_minimize_scalar_brent,
#     976                                       fun, bracket, args, **options)
#     977 elif meth == 'bounded':
#     978     if bounds is None:
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\optimize\_optimize.py:3098, in _recover_from_bracket_error(solver, fun, bracket, args, **options)
#    3079 def _recover_from_bracket_error(solver, fun, bracket, args, **options):
#    3080     # `bracket` was originally written without checking whether the resulting
#    3081     # bracket is valid. `brent` and `golden` built on top of it without
#    (...)
#    3095     # storing the information needed by `minimize_scalar` in the error object,
#    3096     # and intercepting it here.
#    3097     try:
# -> 3098         res = solver(fun, bracket, args, **options)
#    3099     except BracketError as e:
#    3100         msg = str(e)
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\optimize\_optimize.py:2697, in _minimize_scalar_brent(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2694 brent = Brent(func=func, args=args, tol=tol,
#    2695               full_output=True, maxiter=maxiter, disp=disp)
#    2696 brent.set_bracket(brack)
# -> 2697 brent.optimize()
#    2698 x, fval, nit, nfev = brent.get_result(full_output=True)
#    2700 success = nit < maxiter and not (np.isnan(x) or np.isnan(fval))
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\optimize\_optimize.py:2534, in Brent.optimize(self)
#    2532 else:
#    2533     u = x + rat
# -> 2534 fu = func(*((u,) + self.args))      # calculate new output value
#    2535 funcalls += 1
#    2537 if (fu > fx):                 # if it's bigger than current
#
# File ~\Projects\find_similar_music_recommendations\ease_recommender.py:194, in optimize_lambda_using_a_to_b_matching.<locals>.<lambda>(lambda_)
#     192     return round(lambda_*10)
#     193 else:
# --> 194     res = minimize_scalar(lambda lambda_: a_to_b_error_metric(mat, a, b, lambda_),
#     195                           bracket=(lambda_, lambda_*10, lambda_*100))
#     197     return round(res.x)
#
# File ~\Projects\find_similar_music_recommendations\ease_recommender.py:166, in a_to_b_error_metric(mat, a, b, lambda_, verbose)
#     163 similarity_scores_a = calculate_ease_for_item_cg(mat, a, lambda_)
#     164 ranking_a = np.argsort(-similarity_scores_a)
# --> 166 similarity_scores_b = calculate_ease_for_item_cg(mat, b, lambda_)
#     167 ranking_b = np.argsort(-similarity_scores_b)
#     169 # lower is better
#
# File ~\Projects\find_similar_music_recommendations\ease_recommender.py:35, in calculate_ease_for_item_cg(X, item_id, lambda_)
#      31 A = LinearOperator(shape=(n_items, n_items), matvec=matvec_operator)
#      33 # 3. Solve the linear system A * x = b using the operator.
#      34 # The solver 'A' is now just a function, not a giant matrix.
# ---> 35 similarities, _ = cg(A, target_col, maxiter=20)
#      37 # 4. Enforce the B_jj = 0 constraint in the final result
#      38 similarities[item_id] = 0
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\linalg\_isolve\iterative.py:411, in cg(A, b, x0, rtol, atol, maxiter, M, callback)
#     408     p = np.empty_like(r)
#     409     p[:] = z[:]
# --> 411 q = matvec(p)
#     412 alpha = rho_cur / dotprod(p, q)
#     413 x += alpha*p
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\linalg\_interface.py:258, in LinearOperator.matvec(self, x)
#     255 if x.shape != (N,) and x.shape != (N,1):
#     256     raise ValueError('dimension mismatch')
# --> 258 y = self._matvec(x)
#     260 if isinstance(x, np.matrix):
#     261     y = asmatrix(y)
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\linalg\_interface.py:617, in _CustomLinearOperator._matvec(self, x)
#     616 def _matvec(self, x):
# --> 617     return self.__matvec_impl(x)
#
# File ~\Projects\find_similar_music_recommendations\ease_recommender.py:27, in calculate_ease_for_item_cg.<locals>.matvec_operator(v)
#      25 def matvec_operator(v):
#      26     # This is calculated as (X.T @ (X @ v)) + (λ * v)
# ---> 27     return X.T @ (X @ v) + lambda_ * v
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\_base.py:732, in _spbase.__matmul__(self, other)
#     729 if isscalarlike(other):
#     730     raise ValueError("Scalar operands are not allowed, "
#     731                      "use '*' instead")
# --> 732 return self._matmul_dispatch(other)
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\_base.py:617, in _spbase._matmul_dispatch(self, other)
#     614 if other.__class__ is np.ndarray:
#     615     # Fast path for the most common case
#     616     if other.shape == (N,):
# --> 617         return self._matmul_vector(other)
#     618     elif other.shape == (N, 1):
#     619         result = self._matmul_vector(other.ravel())
#
# File ~\miniconda3\envs\recsys\lib\site-packages\scipy\sparse\_compressed.py:526, in _cs_matrix._matmul_vector(self, other)
#     524 # csr_matvec or csc_matvec
#     525 fn = getattr(_sparsetools, self.format + '_matvec')
# --> 526 fn(M, N, self.indptr, self.indices, self.data, other, result)
#     528 return result[0] if self.ndim == 1 else result
#
# KeyboardInterrupt:

# %%
lambda_ = 100

# %%
# check final error for EASE
a_to_b_error_metric(artist_mat, a, b, lambda_)
# Out:
# lambda_: 100
# error: 3.0
# 3.0

# %%
top_k = 20

# %%
# using EASE

similarity_scores = calculate_ease_for_item_cg(artist_mat, a, lambda_)
top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Allman Brown (spotify:artist:239Y6QdFqVFfdsw6moqSEN)',
#  'PHOX (spotify:artist:3ix4iw2URncSdE7X292bXy)',
#  'The Acid (spotify:artist:0bRtSoJSpQdnbB3dWrWprR)',
#  'Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)',
#  'Dustin Tebbutt (spotify:artist:0z9hynUsIjf0ddI4uHqPWX)',
#  'The Careful Ones (spotify:artist:1DdAoWvETBUklcJCOISZx1)',
#  'Liza Anne (spotify:artist:426VSUSxx9puUYFgp7l7EQ)',
#  'Snakadaktal (spotify:artist:0SdEkx5Ai2gl0W7pnhlsfy)',
#  'Vök (spotify:artist:7oDTyDfeA2JE2jUZztkBj8)',
#  'Seoul (spotify:artist:3e69LorE0YSsEaYY6x9XuG)',
#  'Only Real (spotify:artist:5cyHu7tidauRJ9UawaPwG5)',
#  'Big Scary (spotify:artist:4mLYW48jy9Pwv6KpT74Evf)',
#  'SOHN (spotify:artist:6XZYAWJLL8UIbxAqjKj3cg)',
#  'San Fermin (spotify:artist:7fSnislKgW9Mz0YIqWQmGt)',
#  'Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO)',
#  'Caroline Smith (spotify:artist:47blM5Op3BJODxUJImwdYE)',
#  'Neulore (spotify:artist:6SLbaDa56f1CZlUNuF0gk3)',
#  'Lo-Fang (spotify:artist:5EDkJDlRNcMs3ewliB24QA)',
#  'Ásgeir Trausti (spotify:artist:7fNWySjsDn74LCawyJ27EQ)',
#  'Samaris (spotify:artist:1Xl5hsislt88ijOD3EZsOY)']

# %%
# using EASE

similarity_scores = calculate_ease_for_item_cg(artist_mat, b, lambda_)
top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Susanne Sundfør (spotify:artist:54KCNI7URCrG6yjQK3Ukow)',
#  'Gabrielle (spotify:artist:4OovmAu23KrDlDQI2UbneL)',
#  'Elsa & Emilie (spotify:artist:4HDNQLqhooVfWXtIRMyqMY)',
#  'Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)',
#  'Alice Boman (spotify:artist:3WiytRnvoL0kT3oAGl9TCt)',
#  'Majical Cloudz (spotify:artist:4BEYBN6NCPrFk3sOLMTby3)',
#  'Rockettothesky (spotify:artist:0nu7qEOc8X8UFK10d8lsLw)',
#  'Nils Bech (spotify:artist:57QhXfAsLsIRtgC1VfHu1F)',
#  'Rubblebucket (spotify:artist:6xriZDSK3wPXhOoZXr9fzF)',
#  'Ings (spotify:artist:3wJ2NeHF58Im2tojNX8ESR)',
#  'Max Jury (spotify:artist:3MuPVbFDynbq9zRTAqjRxi)',
#  'SOAK (spotify:artist:4PLsMEk2DCRVlVL2a9aZAv)',
#  'Amason (spotify:artist:4cJKxS7uOPhwb5UQ70sYpN)',
#  'Joseph (spotify:artist:5Wfvw7rDz7HA6gE2z6QhqO)',
#  'MUNA (spotify:artist:6xdRb2GypJ7DqnWAI2mHGn)',
#  'Kjartan Lauritzen (spotify:artist:0TW5M8RYADmgeCP1q523hf)',
#  'The Dø (spotify:artist:2mcNCn1qbZUQ3J9KHapUxj)',
#  'Karpe Diem (spotify:artist:3X23gpg1vPacr0hBARyxtN)',
#  'Matrimony (spotify:artist:4V5UtbLYaFishr7psURF3Q)',
#  'Phoria (spotify:artist:0HDxlFsXwyrpufs4YgTNMm)']

# %%
# using EASE

similarity_scores_a = calculate_ease_for_item_cg(artist_mat, a, lambda_) 
similarity_scores_b = calculate_ease_for_item_cg(artist_mat, b, lambda_) 

similarity_scores = similarity_scores_a + similarity_scores_b 
top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Allman Brown (spotify:artist:239Y6QdFqVFfdsw6moqSEN)',
#  'Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO)',
#  'Vök (spotify:artist:7oDTyDfeA2JE2jUZztkBj8)',
#  'Júníus Meyvant (spotify:artist:5IL5awl9gUcb2ez9IgmW26)',
#  'The Dø (spotify:artist:2mcNCn1qbZUQ3J9KHapUxj)',
#  'The Acid (spotify:artist:0bRtSoJSpQdnbB3dWrWprR)',
#  'PHOX (spotify:artist:3ix4iw2URncSdE7X292bXy)',
#  'Mimicking Birds (spotify:artist:5PifaykkaJRJlWbUz3H0od)',
#  'Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)',
#  'San Fermin (spotify:artist:7fSnislKgW9Mz0YIqWQmGt)',
#  'Only Real (spotify:artist:5cyHu7tidauRJ9UawaPwG5)',
#  'Big Scary (spotify:artist:4mLYW48jy9Pwv6KpT74Evf)',
#  'Susanne Sundfør (spotify:artist:54KCNI7URCrG6yjQK3Ukow)',
#  'Dustin Tebbutt (spotify:artist:0z9hynUsIjf0ddI4uHqPWX)',
#  'Amason (spotify:artist:4cJKxS7uOPhwb5UQ70sYpN)',
#  'Neulore (spotify:artist:6SLbaDa56f1CZlUNuF0gk3)',
#  'Lo-Fang (spotify:artist:5EDkJDlRNcMs3ewliB24QA)',
#  'Liza Anne (spotify:artist:426VSUSxx9puUYFgp7l7EQ)',
#  'The Careful Ones (spotify:artist:1DdAoWvETBUklcJCOISZx1)',
#  'Sin Fang (spotify:artist:7xsi0kBJ58yWMu4WXFYPHU)']

# %%
lambda_
# Out:
# 100

# %%
eps = 1e-14
# eps = 0

lambda_ = .09

i, j = a, b
# i, j = b, a

mat = artist_mat
mat = csr_array(mat)

# py = mat.mean(axis=0)
# pxy = (mat[:, i:i+1] * mat).mean(axis=0) + eps
# px = py[i]

py = mat.mean(axis=0)
pxy = (mat[:, i:i+1] * mat).mean(axis=0) + eps
px = py[i]

npmi = (np.log2(pxy + o) - (np.log2(px + np.sqrt(o)) + np.log2(py + np.sqrt(o)))) / -np.log2(pxy + o)

# o = .25
# npmi = (np.log2(pxy + o**2)) - (np.log2(px + o) + np.log2(py + o)) / -np.log2(pxy + o**2)

# score = pxy / np.where(px > py, px, py)
# score = pxy / np.where(px < py, px, py)
# score = pxy / (px * py)
# score = pxy / np.sqrt((px * py))
# score = pxy / (px + py)
# score = pxy / ((px + py)/2)

# score = npmi_batch_popularity_weighted(mat, i, lambda_, cache=(npmi, pxy), eps=eps)
score = npmi

top_k_matches = [idx2cat[idx] for idx in np.argsort(-score)[:top_k].tolist()]

np.argsort(-score).tolist().index(j)
# Out:
# 26

# %%
top_k_matches
# Out:
# ['Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)',
#  'Dustin Tebbutt (spotify:artist:0z9hynUsIjf0ddI4uHqPWX)',
#  'SOHN (spotify:artist:6XZYAWJLL8UIbxAqjKj3cg)',
#  'Lo-Fang (spotify:artist:5EDkJDlRNcMs3ewliB24QA)',
#  'Novo Amor (spotify:artist:0rZp7G3gIH6WkyeXbrZnGi)',
#  'Allman Brown (spotify:artist:239Y6QdFqVFfdsw6moqSEN)',
#  "Bear's Den (spotify:artist:0nJaMZM8paoA5HEUTUXPqi)",
#  'James Vincent McMorrow (spotify:artist:7FDlvgcodNfC0IBdWevl4u)',
#  'London Grammar (spotify:artist:3Bd1cgCjtCI32PYvDC3ynO)',
#  'Liza Anne (spotify:artist:426VSUSxx9puUYFgp7l7EQ)',
#  'Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO)',
#  'PHOX (spotify:artist:3ix4iw2URncSdE7X292bXy)',
#  'S. Carey (spotify:artist:2LSJrlndCuTpdEluvYHc2E)',
#  'Nick Mulvey (spotify:artist:3x8FbPjh2Qz55XMdE2Yalj)',
#  'Ed Tullett (spotify:artist:5VGsR5wapeJIuRPX26IeGn)',
#  'Matt Corby (spotify:artist:7CIW23FQUXPc1zebnO1TDG)',
#  'José González (spotify:artist:6xrCU6zdcSTsG2hLrojpmI)',
#  'Little May (spotify:artist:0TjAAwE04BeoSeOpJIakYH)',
#  'The Acid (spotify:artist:0bRtSoJSpQdnbB3dWrWprR)',
#  'Panama (spotify:artist:3W9UldYu0xJcaOAw2SUTDI)']

# %%
def make_cache(i, j):
    mat = artist_mat
    mat = csr_array(mat)

    py = mat.mean(axis=0)
    pxy = (mat[:, i:i+1] * mat).mean(axis=0) + eps
    px = py[i]

    npmi = (np.log2(pxy) - (np.log2(px) + np.log2(py))) / -np.log2(pxy)
    
    return (npmi, pxy)

# %%
from tqdm.auto import tqdm

eps = 1e-14

cache_a = make_cache(a, b)
cache_b = make_cache(b, a)

lambdas = np.linspace(0, 1, 100)

rankings_a = []
rankings_b = []
rankings_combined = []
for lambda_ in tqdm(lambdas):
#     score = npmi_batch_popularity_weighted(mat, i, lambda_, cache=(npmi, pxy), eps=eps)
#     rankings.append(np.argsort(-score).tolist().index(j))

    score_a = npmi_batch_popularity_weighted(mat, a, lambda_, cache=cache_a, eps=eps)
    score_b = npmi_batch_popularity_weighted(mat, b, lambda_, cache=cache_b, eps=eps)
    
    rankings_a.append(np.argsort(-score_a).tolist().index(b))
    rankings_b.append(np.argsort(-score_b).tolist().index(a))
    rankings_combined.append((rankings_a[-1] + rankings_b[-1])/2)

# min(np.diff(rankings))

import matplotlib.pyplot as plt

rankings = rankings_combined

plt.plot(lambdas, rankings);
plt.axvline(lambdas[np.argmin(rankings)]);
plt.axvline(.14, c="tab:orange");
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
lambdas[np.argmin(rankings)]
# Out:
# np.float64(0.15151515151515152)

# %%
min(rankings)
# Out:
# 50.5

# %%
lambda_ = optimize_lambda_using_a_to_b_matching_npmi(artist_mat, a, b)
# Out:
# lambda_: 0.0
# error: 1806.0
# lambda_: 1.0
# error: 426
# lambda_: 2.6180339999999998
# error: 625
# lambda_: 1.6180339748439998
# error: 518
# lambda_: 0.618034
# error: 305.618034
# lambda_: 0.381966025156
# error: 198.381966025156
# lambda_: 0.23606799039126328
# error: 133.23606799039126
# lambda_: 0.145898044373474
# error: 101.14589804437347
# lambda_: 0.09016995195631564
# error: 355.09016995195634
# lambda_: 0.1803398979741049
# error: 107.18033989797411
# lambda_: 0.136098829051948
# error: 99.13609882905195
# lambda_: 0.11855555958323769
# error: 189.11855555958323
# lambda_: 0.1293978965860626
# error: 189.12939789658606
# lambda_: 0.13984179613145
# error: 101.13984179613145
# lambda_: 0.13353930068168363
# error: 193.1335393006817
# lambda_: 0.13752851521543707
# error: 99.13752851521544
# lambda_: 0.13681150750011398
# error: 99.13681150750011
# lambda_: 0.1351211762384716
# error: 96.13512117623847
# lambda_: 0.13451695355954754
# error: 95.13451695355955
# lambda_: 0.13389245935456162
# error: 193.13389245935457
# lambda_: 0.1342784180060459
# error: 95.13427841800605
# lambda_: 0.13439743117597827
# error: 95.13439743117598
# lambda_: 0.13413099492377306
# error: 95.13413099492378
# lambda_: 0.13403988244654363
# error: 193.13403988244653
# lambda_: 0.1341873055288165
# error: 95.13418730552881
# lambda_: 0.13409619305529566
# error: 95.1340961930553
# lambda_: 0.1340746843173131
# error: 193.1340746843173
# lambda_: 0.1341094861857905
# error: 95.13410948618579
# lambda_: 0.13408797744868342
# error: 95.13408797744869
# lambda_: 0.13408289992446643
# error: 193.13408289992446
# lambda_: 0.13409111553107866
# error: 95.13409111553108
# lambda_: 0.13408603800706836
# error: 193.13408603800707
# lambda_: 0.1340891760894636
# error: 95.13408917608946
# lambda_: 0.1340872366479275
# error: 95.13408723664793
# lambda_: 0.1340867788078731
# error: 95.13408677880787
# lambda_: 0.1340864958471529
# error: 95.13408649584716
# lambda_: 0.13408632096780718
# error: 95.13408632096781
# lambda_: 0.1340862128864256
# error: 95.13408621288643
# lambda_: 0.13408614608845704
# error: 95.13408614608846
# lambda_: 0.13408610480504132
# error: 95.13408610480504
# lambda_: 0.13408607929048677
# error: 95.13408607929048
# lambda_: 0.13408606352162458
# error: 193.13408606352164
# lambda_: 0.1340860890361791
# error: 95.13408608903617
# lambda_: 0.13408607326731756
# error: 95.13408607326731
# lambda_: 0.13408606954479418
# error: 193.1340860695448
# lambda_: 0.1340860755679634
# error: 95.13408607556796

# %%
a_to_b_error_metric_npmi_pop_weighted(artist_mat, a, b, lambda_)
# Out:
# lambda_: 0.13408607326731756
# error: 47.5
# 47.5

# %%
def metric(i, j, o, call_again = True, eps = 1e-14):
    mat = artist_mat
    mat = csr_array(mat)

    py = mat.mean(axis=0)
    pxy = (mat[:, i:i+1] * mat).mean(axis=0) + eps
    px = py[i]
    
#     py = (py * o) + (.5 * (1 - o))
#     px = (px * o) + (.5 * (1 - o))
#     pxy = (pxy * o) + (.5**2 * (1 - o))
#     pxy = (pxy * o) + ((px * py) * (1 - o))

#     px = py = np.where(px > py, px, py)
    px = py = (px + py)/2
#     px = py = px + py

#     px = np.where(px > py, px, py)
#     px = (px + py)/2
#     px = px + py
    
#     py = np.where(px > py, px, py)
#     py = (px + py)/2
#     py = px + py

#     py = np.where(px < py, px, py)
    score = (np.log2(pxy) - (np.log2(px) + np.log2(py))) / -np.log2(pxy)

    if call_again:
        return (metric(j, i, o, call_again = False, eps=eps) + np.argsort(-score).tolist().index(j))/2
    else:
        return np.argsort(-score).tolist().index(j)

# %%
metric(a, b, .6)
# Out:
# 98.5

# %%
metric(a, b, .11)
# Out:
# 105.0

# %%
top_k_matches
# Out:
# ['Ásgeir (spotify:artist:7xUZ4069zcyBM4Bn10NQ1c)',
#  'Dustin Tebbutt (spotify:artist:0z9hynUsIjf0ddI4uHqPWX)',
#  'Ed Tullett (spotify:artist:5VGsR5wapeJIuRPX26IeGn)',
#  'Allman Brown (spotify:artist:239Y6QdFqVFfdsw6moqSEN)',
#  'Quiet Arrows (spotify:artist:7KRnRH8bRvoX4ebQwHw2EI)',
#  'Ásgeir Trausti (spotify:artist:7fNWySjsDn74LCawyJ27EQ)',
#  'Vök (spotify:artist:7oDTyDfeA2JE2jUZztkBj8)',
#  'Highasakite (spotify:artist:5awQWdBpLqN2KFVRN8w56T)',
#  'Liza Anne (spotify:artist:426VSUSxx9puUYFgp7l7EQ)',
#  'The Careful Ones (spotify:artist:1DdAoWvETBUklcJCOISZx1)',
#  'This, the Silent War (spotify:artist:3156bBfcG5gFSWrftU8gaR)',
#  'The Acid (spotify:artist:0bRtSoJSpQdnbB3dWrWprR)',
#  'Josh Jenkins (spotify:artist:20nyUQUh2kYdqOauF3y3Pu)',
#  'Choir Of Young Believers (spotify:artist:4aXPrNXYJLziXeH7Obkea7)',
#  'Samaris (spotify:artist:1Xl5hsislt88ijOD3EZsOY)',
#  'Mimicking Birds (spotify:artist:5PifaykkaJRJlWbUz3H0od)',
#  'Adurn (spotify:artist:4hDzPWJ7vNSD2wCEF49w8r)',
#  'Joe Banfi (spotify:artist:5XuI2JDHFlW8CHzVzje9a1)',
#  'Fairground Lights (spotify:artist:4Oa7XovU6ZSmuZfjwPVooU)',
#  'Alex&Sam (spotify:artist:1smx85wK7Fhp2ledaoytgB)']

# %%
lambda_ = optimize_lambda_using_a_to_b_matching_npmi(artist_mat, a, b)
# Out:
# lambda_: 0.0
# error: 1806.0
# lambda_: 1.0
# error: 426
# lambda_: 2.6180339999999998
# error: 625
# lambda_: 1.6180339748439998
# error: 518
# lambda_: 0.618034
# error: 305.618034
# lambda_: 0.381966025156
# error: 198.381966025156
# lambda_: 0.23606799039126328
# error: 133.23606799039126
# lambda_: 0.145898044373474
# error: 101.14589804437347
# lambda_: 0.09016995195631564
# error: 355.09016995195634
# lambda_: 0.1803398979741049
# error: 107.18033989797411
# lambda_: 0.136098829051948
# error: 99.13609882905195
# lambda_: 0.11855555958323769
# error: 189.11855555958323
# lambda_: 0.1293978965860626
# error: 189.12939789658606
# lambda_: 0.13984179613145
# error: 101.13984179613145
# lambda_: 0.13353930068168363
# error: 193.1335393006817
# lambda_: 0.13752851521543707
# error: 99.13752851521544
# lambda_: 0.13681150750011398
# error: 99.13681150750011
# lambda_: 0.1351211762384716
# error: 96.13512117623847
# lambda_: 0.13451695355954754
# error: 95.13451695355955
# lambda_: 0.13389245935456162
# error: 193.13389245935457
# lambda_: 0.1342784180060459
# error: 95.13427841800605
# lambda_: 0.13439743117597827
# error: 95.13439743117598
# lambda_: 0.13413099492377306
# error: 95.13413099492378
# lambda_: 0.13403988244654363
# error: 193.13403988244653
# lambda_: 0.1341873055288165
# error: 95.13418730552881
# lambda_: 0.13409619305529566
# error: 95.1340961930553
# lambda_: 0.1340746843173131
# error: 193.1340746843173
# lambda_: 0.1341094861857905
# error: 95.13410948618579
# lambda_: 0.13408797744868342
# error: 95.13408797744869
# lambda_: 0.13408289992446643
# error: 193.13408289992446
# lambda_: 0.13409111553107866
# error: 95.13409111553108
# lambda_: 0.13408603800706836
# error: 193.13408603800707
# lambda_: 0.1340891760894636
# error: 95.13408917608946
# lambda_: 0.1340872366479275
# error: 95.13408723664793
# lambda_: 0.1340867788078731
# error: 95.13408677880787
# lambda_: 0.1340864958471529
# error: 95.13408649584716
# lambda_: 0.13408632096780718
# error: 95.13408632096781
# lambda_: 0.1340862128864256
# error: 95.13408621288643
# lambda_: 0.13408614608845704
# error: 95.13408614608846
# lambda_: 0.13408610480504132
# error: 95.13408610480504
# lambda_: 0.13408607929048677
# error: 95.13408607929048
# lambda_: 0.13408606352162458
# error: 193.13408606352164
# lambda_: 0.1340860890361791
# error: 95.13408608903617
# lambda_: 0.13408607326731756
# error: 95.13408607326731
# lambda_: 0.13408606954479418
# error: 193.1340860695448
# lambda_: 0.1340860755679634
# error: 95.13408607556796

# %%
top_k = 20

# %%
# using normalized pointwise mutual information (popularity weighted)

similarity_scores = npmi_batch_popularity_weighted(artist_mat, a, lambda_)

top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['Hanzee (spotify:artist:5yM1po4NHvE2yE1Kf84LWJ)',
#  'Nils Bech (spotify:artist:57QhXfAsLsIRtgC1VfHu1F)',
#  'Rockettothesky (spotify:artist:0nu7qEOc8X8UFK10d8lsLw)',
#  'Ganic (spotify:artist:2qT4UNxM0aOz52gpSXuooT)',
#  'Feitn Fra Kolbotn (spotify:artist:5pTo5SvSAVsfJ9vbVwQyUt)',
#  'ZL-Project (spotify:artist:4w8PGLhS3yzYSzeV3x2hkA)',
#  'Elsa & Emilie (spotify:artist:4HDNQLqhooVfWXtIRMyqMY)',
#  'Kjartan Lauritzen (spotify:artist:0TW5M8RYADmgeCP1q523hf)',
#  'Gabrielle (spotify:artist:4OovmAu23KrDlDQI2UbneL)',
#  'Surferosa (spotify:artist:5WUYimkWakv41ZVVIq3BDr)',
#  'Mikkel Øwre (spotify:artist:1kNHqkERzDBPrzdK9DogGQ)',
#  'Pieces of Juno (spotify:artist:1k88AWvVVqKbz6C0kK624d)',
#  'Ings (spotify:artist:3wJ2NeHF58Im2tojNX8ESR)',
#  'A-Laget (spotify:artist:2eJz0fbC9ZqBL3mGWPBvI5)',
#  'The White Birch (spotify:artist:3pDnwHQUEXbkNX3cvidKpG)',
#  'Carl Louis (spotify:artist:5LY4Rzduoz5b0qZdV3rHwK)',
#  'Susanne Sundfør (spotify:artist:54KCNI7URCrG6yjQK3Ukow)',
#  'Morten Myklebust (spotify:artist:7zFc6IlzgDwyXojYH1GIkI)',
#  'Karpe Diem (spotify:artist:3X23gpg1vPacr0hBARyxtN)',
#  'The Ghost In You (spotify:artist:6YAwcFEMfoZdWD75Uzxsq4)']

# %%
# using normalized pointwise mutual information (popularity weighted)

similarity_scores = npmi_batch_popularity_weighted(artist_mat, b, lambda_)

top_k_matches = [idx2cat[idx] for idx in np.argsort(-similarity_scores)[:top_k].tolist()]

top_k_matches
# Out:
# ['James Vincent McMorrow (spotify:artist:7FDlvgcodNfC0IBdWevl4u)',
#  'Dustin Tebbutt (spotify:artist:0z9hynUsIjf0ddI4uHqPWX)',
#  'José González (spotify:artist:6xrCU6zdcSTsG2hLrojpmI)',
#  'Sylvan Esso (spotify:artist:39vA9YljbnOApXKniLWBZv)',
#  'SOHN (spotify:artist:6XZYAWJLL8UIbxAqjKj3cg)',
#  'Ben Howard (spotify:artist:5schNIzWdI9gJ1QRK8SBnc)',
#  "Bear's Den (spotify:artist:0nJaMZM8paoA5HEUTUXPqi)",
#  'Lo-Fang (spotify:artist:5EDkJDlRNcMs3ewliB24QA)',
#  'Novo Amor (spotify:artist:0rZp7G3gIH6WkyeXbrZnGi)',
#  'London Grammar (spotify:artist:3Bd1cgCjtCI32PYvDC3ynO)',
#  'Chet Faker (spotify:artist:2Q0MyH5YMI5HPQjFjlq5g3)',
#  'Ásgeir Trausti (spotify:artist:7fNWySjsDn74LCawyJ27EQ)',
#  'James Blake (spotify:artist:53KwLdlmrlCelAZMaLVZqU)',
#  'The Paper Kites (spotify:artist:79hrYiudVcFyyxyJW0ipTy)',
#  'Matt Corby (spotify:artist:7CIW23FQUXPc1zebnO1TDG)',
#  'Low Volts (spotify:artist:3PxUwSSsVaW0XyBiRJF2oS)',
#  'Allman Brown (spotify:artist:239Y6QdFqVFfdsw6moqSEN)',
#  'Panama (spotify:artist:3W9UldYu0xJcaOAw2SUTDI)',
#  'Volcano Choir (spotify:artist:6gAtOqhriLzOzb3Qqmg5kO)',
#  'Quiet Arrows (spotify:artist:7KRnRH8bRvoX4ebQwHw2EI)']
